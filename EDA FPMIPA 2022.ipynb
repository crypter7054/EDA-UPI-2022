# %% [markdown]
# # Exploratory Data Analysis FPMIPA UPI 2022
# #### Dataset : https://github.com/crypter7054/EDA-UPI-2022
# #### Keterangan Atribut :
# - **name** = nama dosen
# - **sinta_id**  = id dosen pada website SINTA
# - **dept** = program studi
# - **sinta_score** = skor keseluruhan SINTA
# - **sinta_3yr_score** = skor SINTA dalam 3 tahun terakhir
# - **affil_score** = skor keseluruhan afiliasi
# - **affil_3yr_score** = skor afiliasi dalam 3 tahun terakhir
# - **scopus_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Scopus
# - **gs_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Google Scholar
# - **wos_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Web of Science
# - **scopus_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Scopus
# - **gs_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Google Scholar
# - **wos_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Web of Science
# - **scopus_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Scopus
# - **gs_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Google Scholar
# - **wos_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Web of Science
# - **scopus_article** = jumlah publikasi artikel dosen pada Scopus
# - **scopus_citation** = jumlah sitasi pada publikasi dosen pada Scopus
# - **scopus_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Scopus
# - **gs_article** = jumlah publikasi artikel dosen pada Google Scholar
# - **gs_citation** = jumlah sitasi pada publikasi dosen pada Google Scholar
# - **gs_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Google Scholar
# - **wos_article** = jumlah publikasi artikel dosen pada Web of Science
# - **wos_citation** = jumlah sitasi pada publikasi dosen pada Web of Science
# - **wos_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Web of Science

# %% [markdown]
# Nama Fakultas: FAKULTAS PENDIDIKAN MATEMATIKA DAN ILMU PENGETAHUAN ALAM
#
# Sumber Data: SINTA (Agustus 2022)
#
# Versi Dokumen: 01/140922
#
# Disiapkan oleh: pusdat@upi.edu

# %% [markdown]
# ### Import Library

# %%
# %matplotlib inline
import numpy as np                  
import pandas as pd                 
import matplotlib.pyplot as plt     
import seaborn as sns
from matplotlib import rc
import matplotlib.colors as mcolors
from datetime import datetime, date
from IPython.core.display import HTML
import textwrap
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

sns.set_theme(style="whitegrid", palette="deep")

# %% [markdown]
# ### Read Data

# %%
data = pd.read_csv("C:\\Users\\LENOVO\\Scraper-SINTA-UPI-2022\\EDA-UPI-2022\\data\\dosen_praproses.csv", encoding='utf-8')
df = data[data['Fakultas'] == 'FPMIPA']
df.head(1550)
# Out:
#                      NIP                                         nama  \
# 428   196603252001121001                    Prof. Dr. H. Munir, M.IT.
# 429   195802011984031001             Prof. Dr. H. Didi Suryadi, M.Ed.
# 430   196210111991011001            Prof. Dr. H. Tatang Herman, M.Ed.
# 431   195909221983031003  Prof. H. Yaya Sukjaya Kusumah, M.Sc., Ph.D.
# 432   196204261987031002         Prof. Dr. Parlindungan Sinaga, M.Si.
# ...                  ...                                          ...
# 1224  920200419910906201            Triannisa Rahmawati, S.Pd., M.Si.
# 1225  920200419930502101                 Hafiz Aji Aziz, S.Si., M.Sc.
# 1226  920200419930811201                     Ani Anisyah, S.Pd., M.T.
# 1227  920200419941231201           Andini Setya Arianti, S.Ds., M.Ds.
# 1228  920200419950110201                 Mita Nurhayati, S.Pd., M.Si.
#
#      Stat.Peg    Gol Jabatan Fungsional Pendidikan Terakhir Fakultas  \
# 428       PNS   IV/e         Guru Besar                  S3   FPMIPA
# 429       PNS   IV/d         Guru Besar                  S3   FPMIPA
# 430       PNS   IV/d         Guru Besar                  S3   FPMIPA
# 431       PNS   IV/d         Guru Besar                  S3   FPMIPA
# 432       PNS   IV/c         Guru Besar                  S3   FPMIPA
# ...       ...    ...                ...                 ...      ...
# 1224       PT  III/b    Tenaga Pengajar                  S2   FPMIPA
# 1225       PT  III/b    Tenaga Pengajar                  S2   FPMIPA
# 1226       PT  III/b    Tenaga Pengajar                  S2   FPMIPA
# 1227       PT  III/b    Tenaga Pengajar                  S2   FPMIPA
# 1228       PT  III/b    Tenaga Pengajar                  S2   FPMIPA
#
#       Kode Prodi                             Nama Prodi   sinta_id  ...  \
# 428      83105.0          Pendidikan Ilmu Komputer (S2)  5974517.0  ...
# 429      84002.0             Pendidikan Matematika (S3)  5994183.0  ...
# 430      86022.0                  Pendidikan Dasar (S3)  5986217.0  ...
# 431      84002.0             Pendidikan Matematika (S3)  6676817.0  ...
# 432      84001.0  Pendidikan Ilmu Pengetahuan Alam (S3)  5989835.0  ...
# ...          ...                                    ...        ...  ...
# 1224     84204.0                  Pendidikan Kimia (S1)  6745962.0  ...
# 1225     47201.0                             Kimia (S1)  6748855.0  ...
# 1226     55201.0                     Ilmu Komputer (S1)  6786982.0  ...
# 1227     83207.0          Pendidikan Ilmu Komputer (S1)  6751563.0  ...
# 1228     47201.0                             Kimia (S1)  6745947.0  ...
#
#      wos_g_index  scopus_article  scopus_citation  scopus_cited_document  \
# 428          1.0            45.0            105.0                   30.0
# 429          NaN            97.0            217.0                   53.0
# 430          1.0            88.0            245.0                   56.0
# 431          NaN            57.0            268.0                   40.0
# 432          NaN            50.0             97.0                   25.0
# ...          ...             ...              ...                    ...
# 1224         NaN             3.0              6.0                    1.0
# 1225         0.0             8.0             23.0                    5.0
# 1226         NaN             0.0              0.0                    0.0
# 1227         0.0             0.0              0.0                    0.0
# 1228         NaN             7.0              9.0                    3.0
#
#       gs_article  gs_citation  gs_cited_document  wos_article  wos_citation  \
# 428        116.0        601.0               59.0         34.0          43.0
# 429        258.0       2709.0              169.0          0.0           0.0
# 430        222.0       2132.0              145.0         58.0          46.0
# 431        176.0       2153.0              136.0          0.0           0.0
# 432        140.0        706.0               92.0          0.0           0.0
# ...          ...          ...                ...          ...           ...
# 1224         4.0         15.0                3.0          0.0           0.0
# 1225        13.0         36.0                8.0          3.0          14.0
# 1226         2.0          1.0                1.0          0.0           0.0
# 1227         6.0          1.0                1.0          0.0           0.0
# 1228        11.0         13.0                4.0          0.0           0.0
#
#       wos_cited_document
# 428                 19.0
# 429                  0.0
# 430                 24.0
# 431                  0.0
# 432                  0.0
# ...                  ...
# 1224                 0.0
# 1225                 3.0
# 1226                 0.0
# 1227                 0.0
# 1228                 0.0
#
# [193 rows x 32 columns]

# %% [markdown]
# #### Menampilkan jumlah dan tipe data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 428 to 1228
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NIP                    193 non-null    int64
#  1   nama                   193 non-null    object
#  2   Stat.Peg               193 non-null    object
#  3   Gol                    193 non-null    object
#  4   Jabatan Fungsional     193 non-null    object
#  5   Pendidikan Terakhir    193 non-null    object
#  6   Fakultas               193 non-null    object
#  7   Kode Prodi             193 non-null    float64
#  8   Nama Prodi             193 non-null    object
#  9   sinta_id               186 non-null    float64
#  10  Jenis Kelamin          193 non-null    object
#  11  Usia                   193 non-null    int64
#  12  sinta_score            186 non-null    float64
#  13  sinta_3yr_score        186 non-null    float64
#  14  scopus_h_index         186 non-null    float64
#  15  gs_h_index             186 non-null    float64
#  16  wos_h_index            108 non-null    float64
#  17  scopus_i10_index       186 non-null    float64
#  18  gs_i10_index           186 non-null    float64
#  19  wos_i10_index          108 non-null    float64
#  20  scopus_g_index         186 non-null    float64
#  21  gs_g_index             186 non-null    float64
#  22  wos_g_index            108 non-null    float64
#  23  scopus_article         186 non-null    float64
#  24  scopus_citation        186 non-null    float64
#  25  scopus_cited_document  186 non-null    float64
#  26  gs_article             186 non-null    float64
#  27  gs_citation            186 non-null    float64
#  28  gs_cited_document      186 non-null    float64
#  29  wos_article            186 non-null    float64
#  30  wos_citation           186 non-null    float64
#  31  wos_cited_document     186 non-null    float64
# dtypes: float64(22), int64(2), object(8)
# memory usage: 49.8+ KB

# %% [markdown]
# #### Menampilkan jumlah data kosong df

# %%
df.isnull().sum()
# Out:
# NIP                       0
# nama                      0
# Stat.Peg                  0
# Gol                       0
# Jabatan Fungsional        0
# Pendidikan Terakhir       0
# Fakultas                  0
# Kode Prodi                0
# Nama Prodi                0
# sinta_id                  7
# Jenis Kelamin             0
# Usia                      0
# sinta_score               7
# sinta_3yr_score           7
# scopus_h_index            7
# gs_h_index                7
# wos_h_index              85
# scopus_i10_index          7
# gs_i10_index              7
# wos_i10_index            85
# scopus_g_index            7
# gs_g_index                7
# wos_g_index              85
# scopus_article            7
# scopus_citation           7
# scopus_cited_document     7
# gs_article                7
# gs_citation               7
# gs_cited_document         7
# wos_article               7
# wos_citation              7
# wos_cited_document        7
# dtype: int64

# %% [markdown]
# # Jumlah Dosen FPMIPA

# %% [markdown]
# ## Jumlah Dosen FPMIPA Berdasarkan Gender dan Pendidikan Terakhir

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5.8))
fig.tight_layout()
fig.tight_layout(pad=5)

custom_cmap = LinearSegmentedColormap.from_list('custom_camp', ['#f07167', '#0096c7'], N=100)
custom_cmap2 = LinearSegmentedColormap.from_list('custom_camp2', ['#505484', '#489c9c'], N=100)

colors = ["#0096c7", "#f07167", "#1ac938"]
custom_palette1 = sns.set_palette(sns.color_palette(colors))

fig.suptitle("Jumlah Dosen FPMIPA Berdasarkan Gender dan Pendidikan Terakhir"
             , fontsize = 'large', fontweight = 'bold', y=1)

gender = sns.countplot(x='Jenis Kelamin', data = df, palette=custom_palette1, ax=axes[0])
pend = sns.countplot(x='Pendidikan Terakhir', data = df, palette="mako", ax=axes[1])

gender.set_title('Berdasarkan Gender',fontweight="normal", size=13, y=1.05)
gender.set_xlabel('Gender', fontsize = 12)
gender.set_ylabel('Jumlah Dosen')


pend.set_title('Berdasarkan Pendidikan Terakhir',fontweight="normal", size=13, y=1.05)
pend.set_xlabel('Pendidikan Terakhir', fontsize = 12)
pend.set_ylabel('Jumlah Dosen')

gender.text(0,-28,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
pend.text(0,-28,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")


# tampilkan value 
for container in gender.containers:
    gender.bar_label(container, padding=3)
    
for container in pend.containers:
    pend.bar_label(container, padding=3)
    
plt.show()

# %% [markdown]
# ## Jumlah Dosen FPMIPA Berdasarkan Golongan

# %%
plt.figure(figsize=(10, 6))

# deklarasi countplot dengan x sebagai kolom 'Gol', kemudian diurutkan
g = sns.countplot(y="Gol", data = df, order = df['Gol'].value_counts().index, palette="deep")
g.set(ylabel='Golongan', xlabel='Jumlah Dosen')
g.text(0, 10.5,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
plt.suptitle("Jumlah Dosen FPMIPA Berdasarkan Golongan" , fontsize = 'large', fontweight = 'regular')

# tampilkan value
for container in g.containers:
    g.bar_label(container, padding=4)

# %% [markdown]
# ## Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional

# %%
plt.figure(figsize=(8, 4.5))

# deklarasi countplot dengan x sebagai kolom 'Jabatan Fungsional', kemudian diurutkan
g = sns.countplot(y="Jabatan Fungsional", data = df, order = df['Jabatan Fungsional'].value_counts().index, palette="deep")
g.set(ylabel='Jabatan Fungsional', xlabel='Jumlah Dosen')
plt.suptitle("Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional" , fontsize = 'large', fontweight = 'regular')
g.text(0, 5.9,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")


# tampilkan value
for container in g.containers:
    g.bar_label(container, padding=4)

# %% [markdown]
# ## Jumlah Dosen FPMIPA untuk Setiap Program Studi

# %%
plt.figure(figsize=(12, 12))

# deklarasi countplot dengan y sebagai kolom 'Fakultas', kemudian diurutkan
g = sns.countplot(y="Nama Prodi", data=df, order = df['Nama Prodi'].value_counts().index, palette="deep")
g.set(xlabel='Jumlah Dosen', ylabel='Program Studi')
plt.suptitle("Jumlah Dosen FPMIPA untuk Setiap Program Studi" , fontsize = 'large', fontweight = 'regular', y=0.94)
g.text(0, 24, 'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

# tampilkan value
for container in g.containers:
    g.bar_label(container, padding=4)

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Gender untuk Jenjang S1

# %%
df_s1 = df[df["Nama Prodi"].str.contains("S1") == True]
df_s2 = df[df["Nama Prodi"].str.contains("S2") == True]
df_s3 = df[df["Nama Prodi"].str.contains("S3") == True]

df_p = df_s1[df_s1['Jenis Kelamin'] == 'Perempuan']
df_l = df_s1[df_s1['Jenis Kelamin'] == 'Laki-laki']
# df_ss1 = df_w.groupby(['Nama Prodi'])
df_p1 = df_p.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_l1 = df_l.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

df_p1.rename(columns = {'Kode Prodi':'Jumlah Perempuan'}, inplace = True)
df_l1.rename(columns = {'Kode Prodi':'Jumlah Laki-laki'}, inplace = True)

df_final = (pd.merge(df_p1, df_l1, how='left'))

df_final["Jumlah"] = df_final["Jumlah Perempuan"] + df_final["Jumlah Laki-laki"]
df_final["Perempuan"] = ((df_final["Jumlah Perempuan"] / df_final["Jumlah"]) * 100)
df_final["Laki-laki"] = ((df_final["Jumlah Laki-laki"] / df_final["Jumlah"]) * 100)
df_final = df_final.drop(columns=['Jumlah Perempuan', 'Jumlah Laki-laki', 'Jumlah'])


df_final = df_final.sort_values(by="Perempuan", ascending=True)

plt.rcParams["figure.figsize"] = (10, 8)

df_final.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap, 
  mark_right = True)
  
df_total = df_final["Laki-laki"] + df_final["Perempuan"]
df_rel = df_final[df_final.columns[1:]].div(df_total, 0) * 100
  
    
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_final.iloc[:, 1:].cumsum(1)[n], 
                                         df_final[n], df_rel[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='black')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Gender untuk Jenjang S1", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S1")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah perempuan', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Gender untuk Jenjang S2 dan S3

# %%
# df_profesi = df[df["Nama Prodi"].str.contains("Profesi") == True]

df_concat1 = pd.concat([df_s2, df_s3], ignore_index=True)
# df_concat2 = pd.concat([df_concat1, df_profesi], ignore_index=True)

df_pgab = df_concat1[df_concat1['Jenis Kelamin'] == 'Perempuan']
df_lgab = df_concat1[df_concat1['Jenis Kelamin'] == 'Laki-laki']
# df_ss1 = df_w.groupby(['Nama Prodi'])
df_pgab1_temp = df_pgab.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_lgab1 = df_lgab.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

added_gab = [['Pendidikan Matematika (S3)', 0], ['Pendidikan Dasar (S3)', 0], 
            ['Pendidikan Ilmu Komputer (S2)', 0]]
df_added_gab = pd.DataFrame(added_gab, columns=['Nama Prodi', 'Kode Prodi'])

df_pgab1 = pd.concat([df_pgab1_temp, df_added_gab], ignore_index=True)

# df_pgab1.head(100)

df_pgab1.rename(columns = {'Kode Prodi':'Jumlah Perempuan'}, inplace = True)
df_lgab1.rename(columns = {'Kode Prodi':'Jumlah Laki-laki'}, inplace = True)

df_final2 = (pd.merge(df_pgab1, df_lgab1, how='left'))

df_final2["Jumlah"] = df_final2["Jumlah Perempuan"] + df_final2["Jumlah Laki-laki"]
df_final2["Perempuan"] = ((df_final2["Jumlah Perempuan"] / df_final2["Jumlah"]) * 100)
df_final2["Laki-laki"] = ((df_final2["Jumlah Laki-laki"] / df_final2["Jumlah"]) * 100)
df_final2 = df_final2.drop(columns=['Jumlah Perempuan', 'Jumlah Laki-laki', 'Jumlah'])


df_final2 = df_final2.sort_values(by="Perempuan", ascending=True)

plt.rcParams["figure.figsize"] = (10, 8)

df_final2.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap, 
  mark_right = True)
  
df_total2 = df_final2["Laki-laki"] + df_final2["Perempuan"]
df_rel2 = df_final2[df_final2.columns[1:]].div(df_total2, 0) * 100
  
    
for n in df_rel2:
    for i, (cs, ab, pc) in enumerate(zip(df_final2.iloc[:, 1:].cumsum(1)[n], 
                                         df_final2[n], df_rel2[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='black')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Gender untuk Jenjang S2 dan S3", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S2 dan S3")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah perempuan', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Jumlah Dosen FPMIPA Berdasarkan Gender untuk Setiap Program Studi

# %%
plt.figure(figsize=(12, 16))

# deklarasi countplot dengan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin', dan diurutkan
g = sns.countplot(y="Nama Prodi", hue="Jenis Kelamin", data=df, order=df['Nama Prodi'].value_counts().index, palette=custom_palette1)
g.set(xlabel='Jumlah Dosen', ylabel='Program Studi')
plt.suptitle("Jumlah Dosen FPMIPA Berdasarkan Gender untuk Setiap Program Studi", y=0.92, fontsize = 'large', fontweight = 'regular')
g.text(0, 23.3,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

# tampilkan value
for container in g.containers:
    g.bar_label(container, padding=4)

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Pendidikan Terakhir untuk Jenjang S1

# %%
# df_ss1 = df_s1.groupby('Nama Prodi')['nama'].counts()
df_S2 = df_s1[df_s1['Pendidikan Terakhir'] == 'S2']
df_S3 = df_s1[df_s1['Pendidikan Terakhir'] == 'S3']
# df_ss1 = df_w.groupby(['Nama Prodi'])
df_sdua = df_S2.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_stiga_temp = df_S3.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

added = [['Pendidikan Ilmu Komputer (S1)', 0]]
df_added = pd.DataFrame(added, columns=['Nama Prodi', 'Kode Prodi'])

# df_added.head(50)

df_stiga = pd.concat([df_stiga_temp, df_added], ignore_index=True)

# df_stiga.head(50)
df_sdua.rename(columns = {'Kode Prodi':'Jumlah S2'}, inplace = True)
df_stiga.rename(columns = {'Kode Prodi':'Jumlah S3'}, inplace = True)

df_finals = (pd.merge(df_stiga, df_sdua, how='left'))

df_finals["Jumlah"] = df_finals["Jumlah S2"] + df_finals["Jumlah S3"]
df_finals["S3"] = ((df_finals["Jumlah S3"] / df_finals["Jumlah"]) * 100)
df_finals["S2"] = ((df_finals["Jumlah S2"] / df_finals["Jumlah"]) * 100)


df_finals = df_finals.drop(columns=['Jumlah S2', 'Jumlah S3', 'Jumlah'])


df_finals = df_finals.sort_values(by="S3", ascending=True)

plt.rcParams["figure.figsize"] = (10, 8)

df_finals.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap2, 
  mark_right = True)
  
df_total2 = df_finals["S2"] + df_finals["S3"]
df_rel2 = df_finals[df_finals.columns[1:]].div(df_total2, 0) * 100
  
    
for n in df_rel2:
    for i, (cs, ab, pc) in enumerate(zip(df_finals.iloc[:, 1:].cumsum(1)[n], 
                                         df_finals[n], df_rel2[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='white')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Pendidikan Terakhir untuk Jenjang S1", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S1")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah dosen S3', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Jumlah Dosen FPMIPA Berdasarkan Pendidikan Terakhir untuk Setiap Program Studi

# %%
plt.figure(figsize=(12, 16))

# deklarasi countplot dengan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin', dan diurutkan
g = sns.countplot(y="Nama Prodi", hue="Pendidikan Terakhir", data=df, order=df['Nama Prodi'].value_counts().index, palette="mako")
g.set(xlabel='Jumlah Dosen', ylabel='Program Studi')
plt.suptitle("Jumlah Dosen FPMIPA Berdasarkan Pendidikan Terakhir untuk Setiap Program Studi", y=0.92, fontsize = 'large', fontweight = 'regular')
g.text(0, 23.3,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

# tampilkan value
for container in g.containers:
    g.bar_label(container, padding=4)

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Golongan untuk Jenjang S1

# %%
custom_cmap4 = LinearSegmentedColormap.from_list('custom_camp4', ['#5975a4', '#cc8963', '#5f9e6e', '#b55d60', '#857aab', '#8d7866', '#d095bf', '#8c8c8c', '#c1b37f'], N=100)

temp_3a = df_s1[df_s1['Gol'] == 'III/a']
temp_3b = df_s1[df_s1['Gol'] == 'III/b']
temp_3c = df_s1[df_s1['Gol'] == 'III/c']
temp_3d = df_s1[df_s1['Gol'] == 'III/d']
temp_4a = df_s1[df_s1['Gol'] == 'IV/a']
temp_4b = df_s1[df_s1['Gol'] == 'IV/b']
temp_4c = df_s1[df_s1['Gol'] == 'IV/c']
temp_4d = df_s1[df_s1['Gol'] == 'IV/d']
temp_4e = df_s1[df_s1['Gol'] == 'IV/e']

# temp_3a.head(100)
df_3a_temp = temp_3a.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3b_temp = temp_3b.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3c_temp = temp_3c.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3d_temp = temp_3d.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4a_temp = temp_4a.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4b_temp = temp_4b.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4c_temp = temp_4c.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4d_temp = temp_4d.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4e_temp = temp_4e.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

# df_4e_temp.head(200)

added_gol1 = [['Biologi (S1)', 0], ['Pendidikan Matematika (S1)', 0], ['Pendidikan IPA (S1)', 0], ['Matematika (S1)', 0], ['Kimia (S1)', 0], 
             ['Pendidikan Biologi (S1)', 0], ['Pendidikan Ilmu Komputer (S1)', 0], ['Pendidikan Kimia (S1)', 0], ['Fisika (S1)', 0], ['Ilmu Komputer (S1)', 0]]
added_gol2 = [['Biologi (S1)', 0], ['Fisika (S1)', 0], ['Pendidikan Fisika (S1)', 0]]
added_gol3 = [['Biologi (S1)', 0]]
added_gol4 = [['Pendidikan IPA (S1)', 0]]
added_gol5 = [['Ilmu Komputer (S1)', 0]]
added_gol6 = [['Ilmu Komputer (S1)', 0], ['Pendidikan Ilmu Komputer (S1)', 0], ['Pendidikan IPA (S1)', 0], ['Pendidikan Kimia (S1)', 0]]
added_gol7 = [['Kimia (S1)', 0], ['Pendidikan Kimia (S1)', 0], ['Fisika (S1)', 0], ['Pendidikan Fisika (S1)', 0], ['Biologi (S1)', 0], ['Pendidikan Biologi (S1)', 0],
             ['Matematika (S1)', 0], ['Pendidikan Matematika (S1)', 0], ['Ilmu Komputer (S1)', 0], ['Pendidikan Ilmu Komputer (S1)', 0], ['Pendidikan IPA (S1)', 0]]

df_added_gol1 = pd.DataFrame(added_gol1, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol2 = pd.DataFrame(added_gol2, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol3 = pd.DataFrame(added_gol3, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol4 = pd.DataFrame(added_gol4, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol5 = pd.DataFrame(added_gol5, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol6 = pd.DataFrame(added_gol6, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol7 = pd.DataFrame(added_gol7, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol8 = pd.DataFrame(added_gol7, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol9 = pd.DataFrame(added_gol7, columns=['Nama Prodi', 'Kode Prodi'])

# # df_added_jab2.head(50)

df_3a = pd.concat([df_3a_temp, df_added_gol1], ignore_index=True)
df_3b = pd.concat([df_3b_temp, df_added_gol2], ignore_index=True)
df_3c = pd.concat([df_3c_temp, df_added_gol3], ignore_index=True)
df_3d = pd.concat([df_3d_temp, df_added_gol4], ignore_index=True)
df_4a = pd.concat([df_4a_temp, df_added_gol5], ignore_index=True)
df_4b = pd.concat([df_4b_temp, df_added_gol6], ignore_index=True)
df_4c = pd.concat([df_4c_temp, df_added_gol7], ignore_index=True)
df_4d = pd.concat([df_4d_temp, df_added_gol8], ignore_index=True)
df_4e = pd.concat([df_4e_temp, df_added_gol9], ignore_index=True)

# df_4e.head(20)


df_3a.rename(columns = {'Kode Prodi':'Jumlah 3a'}, inplace = True)
df_3b.rename(columns = {'Kode Prodi':'Jumlah 3b'}, inplace = True)
df_3c.rename(columns = {'Kode Prodi':'Jumlah 3c'}, inplace = True)
df_3d.rename(columns = {'Kode Prodi':'Jumlah 3d'}, inplace = True)
df_4a.rename(columns = {'Kode Prodi':'Jumlah 4a'}, inplace = True)
df_4b.rename(columns = {'Kode Prodi':'Jumlah 4b'}, inplace = True)
df_4c.rename(columns = {'Kode Prodi':'Jumlah 4c'}, inplace = True)
df_4d.rename(columns = {'Kode Prodi':'Jumlah 4d'}, inplace = True)
df_4e.rename(columns = {'Kode Prodi':'Jumlah 4e'}, inplace = True)


# # # df_lk.head(100)
df_final_gol1 = (pd.merge(df_3b, df_3a, how='left'))
df_final_gol2 = (pd.merge(df_final_gol1, df_3c, how='left'))
df_final_gol3 = (pd.merge(df_final_gol2, df_3d, how='left'))
df_final_gol4 = (pd.merge(df_final_gol3, df_4a, how='left'))
df_final_gol5 = (pd.merge(df_final_gol4, df_4b, how='left'))
df_final_gol6 = (pd.merge(df_final_gol5, df_4c, how='left'))
df_final_gol7 = (pd.merge(df_final_gol6, df_4d, how='left'))
df_final_gol = (pd.merge(df_final_gol7, df_4e, how='left'))

# df_final_gol.head(20)

df_final_gol["Jumlah"] = df_final_gol["Jumlah 3a"] + df_final_gol["Jumlah 3b"] + df_final_gol["Jumlah 3c"] + df_final_gol["Jumlah 3d"] + df_final_gol["Jumlah 4a"] + df_final_gol["Jumlah 4b"] + df_final_gol["Jumlah 4c"] +df_final_gol["Jumlah 4d"] + df_final_gol["Jumlah 4e"]
df_final_gol["III/a"] = ((df_final_gol["Jumlah 3a"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/b"] = ((df_final_gol["Jumlah 3b"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/c"] = ((df_final_gol["Jumlah 3c"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/d"] = ((df_final_gol["Jumlah 3d"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/a"] = ((df_final_gol["Jumlah 4a"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/b"] = ((df_final_gol["Jumlah 4b"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/c"] = ((df_final_gol["Jumlah 4c"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/d"] = ((df_final_gol["Jumlah 4d"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/e"] = ((df_final_gol["Jumlah 4e"] / df_final_gol["Jumlah"]) * 100)
df_final_gol = df_final_gol.drop(columns=['Jumlah', 'Jumlah 3a', 'Jumlah 3b', 'Jumlah 3c', 'Jumlah 3d', 'Jumlah 4a', 'Jumlah 4b', 'Jumlah 4c', 'Jumlah 4d', 'Jumlah 4e'])

df_final_gol = df_final_gol.sort_values(by="III/b", ascending=True)

plt.rcParams["figure.figsize"] = (10, 8)

df_final_gol.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap4, 
  mark_right = True)
  
df_total_gol = df_final_gol["III/a"] + df_final_gol["III/b"] + df_final_gol["III/c"] + df_final_gol["III/d"] + df_final_gol["IV/a"] + df_final_gol["IV/b"] + df_final_gol["IV/c"] + df_final_gol["IV/d"] + df_final_gol["IV/e"]
df_rel_gol = df_final_gol[df_final_gol.columns[1:]].div(df_total_gol, 0) * 100

# df_rel_gol.head(12)
for n in df_rel_gol:
    for i, (cs, ab, pc) in enumerate(zip(df_final_gol.iloc[:, 1:].cumsum(1)[n], 
                                         df_final_gol[n], df_rel_gol[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='white')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Golongan untuk Jenjang S1", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S1")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah dosen Golongan III/b', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Golongan untuk Jenjang S2 dan S3

# %%
temp_3a = df_concat1[df_concat1['Gol'] == 'III/a']
temp_3b = df_concat1[df_concat1['Gol'] == 'III/b']
temp_3c = df_concat1[df_concat1['Gol'] == 'III/c']
temp_3d = df_concat1[df_concat1['Gol'] == 'III/d']
temp_4a = df_concat1[df_concat1['Gol'] == 'IV/a']
temp_4b = df_concat1[df_concat1['Gol'] == 'IV/b']
temp_4c = df_concat1[df_concat1['Gol'] == 'IV/c']
temp_4d = df_concat1[df_concat1['Gol'] == 'IV/d']
temp_4e = df_concat1[df_concat1['Gol'] == 'IV/e']

# temp_3a.head(100)
df_3a_temp = temp_3a.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3b_temp = temp_3b.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3c_temp = temp_3c.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_3d_temp = temp_3d.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4a_temp = temp_4a.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4b_temp = temp_4b.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4c_temp = temp_4c.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4d_temp = temp_4d.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_4e_temp = temp_4e.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

# df_4e_temp.head(200)

added_gol1 = [['Kimia (S2)', 0], ['Pendidikan Kimia (S2)', 0], ['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0], ['Pendidikan Ilmu Komputer (S2)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_gol2 = [['Pendidikan Kimia (S2)', 0], ['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_gol3 = [['Pendidikan Kimia (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_gol4 = [['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0]]
added_gol5 = [['Pendidikan Dasar (S3)', 0], ['Pendidikan Ilmu Komputer (S2)', 0]]
added_gol6 = [['Kimia (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Ilmu Komputer (S2)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_gol7 = [['Kimia (S2)', 0], ['Pendidikan Ilmu Komputer (S2)', 0], ['Pendidikan Kimia (S2)', 0]]
added_gol8 = [['Kimia (S2)', 0], ['Pendidikan Kimia (S2)', 0], ['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]


df_added_gol1 = pd.DataFrame(added_gol1, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol2 = pd.DataFrame(added_gol1, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol3 = pd.DataFrame(added_gol2, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol4 = pd.DataFrame(added_gol3, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol5 = pd.DataFrame(added_gol4, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol6 = pd.DataFrame(added_gol5, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol7 = pd.DataFrame(added_gol6, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol8 = pd.DataFrame(added_gol7, columns=['Nama Prodi', 'Kode Prodi'])
df_added_gol9 = pd.DataFrame(added_gol8, columns=['Nama Prodi', 'Kode Prodi'])

# # df_added_jab2.head(50)

df_3a = pd.concat([df_3a_temp, df_added_gol1], ignore_index=True)
df_3b = pd.concat([df_3b_temp, df_added_gol2], ignore_index=True)
df_3c = pd.concat([df_3c_temp, df_added_gol3], ignore_index=True)
df_3d = pd.concat([df_3d_temp, df_added_gol4], ignore_index=True)
df_4a = pd.concat([df_4a_temp, df_added_gol5], ignore_index=True)
df_4b = pd.concat([df_4b_temp, df_added_gol6], ignore_index=True)
df_4c = pd.concat([df_4c_temp, df_added_gol7], ignore_index=True)
df_4d = pd.concat([df_4d_temp, df_added_gol8], ignore_index=True)
df_4e = pd.concat([df_4e_temp, df_added_gol9], ignore_index=True)

df_4e.head(20)


df_3a.rename(columns = {'Kode Prodi':'Jumlah 3a'}, inplace = True)
df_3b.rename(columns = {'Kode Prodi':'Jumlah 3b'}, inplace = True)
df_3c.rename(columns = {'Kode Prodi':'Jumlah 3c'}, inplace = True)
df_3d.rename(columns = {'Kode Prodi':'Jumlah 3d'}, inplace = True)
df_4a.rename(columns = {'Kode Prodi':'Jumlah 4a'}, inplace = True)
df_4b.rename(columns = {'Kode Prodi':'Jumlah 4b'}, inplace = True)
df_4c.rename(columns = {'Kode Prodi':'Jumlah 4c'}, inplace = True)
df_4d.rename(columns = {'Kode Prodi':'Jumlah 4d'}, inplace = True)
df_4e.rename(columns = {'Kode Prodi':'Jumlah 4e'}, inplace = True)


# # # # df_lk.head(100)
df_final_gol1 = (pd.merge(df_3b, df_3a, how='left'))
df_final_gol2 = (pd.merge(df_final_gol1, df_3c, how='left'))
df_final_gol3 = (pd.merge(df_final_gol2, df_3d, how='left'))
df_final_gol4 = (pd.merge(df_final_gol3, df_4a, how='left'))
df_final_gol5 = (pd.merge(df_final_gol4, df_4b, how='left'))
df_final_gol6 = (pd.merge(df_final_gol5, df_4c, how='left'))
df_final_gol7 = (pd.merge(df_final_gol6, df_4d, how='left'))
df_final_gol = (pd.merge(df_final_gol7, df_4e, how='left'))

# # df_final_gol.head(20)

df_final_gol["Jumlah"] = df_final_gol["Jumlah 3a"] + df_final_gol["Jumlah 3b"] + df_final_gol["Jumlah 3c"] + df_final_gol["Jumlah 3d"] + df_final_gol["Jumlah 4a"] + df_final_gol["Jumlah 4b"] + df_final_gol["Jumlah 4c"] +df_final_gol["Jumlah 4d"] + df_final_gol["Jumlah 4e"]
df_final_gol["III/a"] = ((df_final_gol["Jumlah 3a"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/b"] = ((df_final_gol["Jumlah 3b"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/c"] = ((df_final_gol["Jumlah 3c"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["III/d"] = ((df_final_gol["Jumlah 3d"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/a"] = ((df_final_gol["Jumlah 4a"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/b"] = ((df_final_gol["Jumlah 4b"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/c"] = ((df_final_gol["Jumlah 4c"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/d"] = ((df_final_gol["Jumlah 4d"] / df_final_gol["Jumlah"]) * 100)
df_final_gol["IV/e"] = ((df_final_gol["Jumlah 4e"] / df_final_gol["Jumlah"]) * 100)
df_final_gol = df_final_gol.drop(columns=['Jumlah', 'Jumlah 3a', 'Jumlah 3b', 'Jumlah 3c', 'Jumlah 3d', 'Jumlah 4a', 'Jumlah 4b', 'Jumlah 4c', 'Jumlah 4d', 'Jumlah 4e'])

df_final_gol = df_final_gol.sort_values(by="IV/a", ascending=True)

plt.rcParams["figure.figsize"] = (10, 8)

df_final_gol.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap4, 
  mark_right = True)
  
df_total_gol = df_final_gol["III/a"] + df_final_gol["III/b"] + df_final_gol["III/c"] + df_final_gol["III/d"] + df_final_gol["IV/a"] + df_final_gol["IV/b"] + df_final_gol["IV/c"] + df_final_gol["IV/d"] + df_final_gol["IV/e"]
df_rel_gol = df_final_gol[df_final_gol.columns[1:]].div(df_total_gol, 0) * 100

# df_rel_gol.head(12)
for n in df_rel_gol:
    for i, (cs, ab, pc) in enumerate(zip(df_final_gol.iloc[:, 1:].cumsum(1)[n], 
                                         df_final_gol[n], df_rel_gol[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='white')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Golongan untuk Jenjang S2 dan S3", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S2 dan S3")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah dosen Golongan IV/a', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional untuk Jenjang S1

# %%
custom_cmap3 = LinearSegmentedColormap.from_list('custom_camp3', ['#5975a4', '#cc8963', '#5f9e6e', '#b55d60', '#857aab'], N=100)

temp_lk = df_s1[df_s1['Jabatan Fungsional'] == 'Lektor Kepala']
temp_lek = df_s1[df_s1['Jabatan Fungsional'] == 'Lektor']
temp_gb = df_s1[df_s1['Jabatan Fungsional'] == 'Guru Besar']
temp_ast = df_s1[df_s1['Jabatan Fungsional'] == 'Asisten Ahli']
temp_tp = df_s1[df_s1['Jabatan Fungsional'] == 'Tenaga Pengajar']

# temp_lk['Kode Prodi'] = temp_lk['Kode Prodi'].fillna(0)
# temp_lk.fillna(0)

# temp_lek.head(100)
df_lk_temp = temp_lk.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_lek = temp_lek.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_gb_temp = temp_gb.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_ast_temp = temp_ast.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_tp_temp = temp_tp.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

df_tp_temp.head(200)

# df_lk_temp['Kode Prodi'] = df_lk_temp['Kode Prodi'].fillna(0)

added_jab1 = [['Ilmu Komputer (S1)', 0]]
added_jab2 = [['Ilmu Komputer (S1)', 0], ['Pendidikan Ilmu Komputer (S1)', 0], ['Pendidikan IPA (S1)', 0], ['Matematika (S1)', 0], 
             ['Kimia (S1)', 0], ['Pendidikan Biologi (S1)', 0], ['Pendidikan Kimia (S1)', 0], ['Fisika (S1)', 0], ['Pendidikan Fisika (S1)', 0]]
added_jab3 = [['Biologi (S1)', 0], ['Matematika (S1)', 0], ['Kimia (S1)', 0], ['Fisika (S1)', 0]]
added_jab4 = [['Biologi (S1)', 0], ['Pendidikan IPA (S1)', 0], ['Matematika (S1)', 0], ['Pendidikan Biologi (S1)', 0],
             ['Fisika (S1)', 0], ['Pendidikan Fisika (S1)', 0]]

df_added_jab1 = pd.DataFrame(added_jab1, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab2 = pd.DataFrame(added_jab2, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab3 = pd.DataFrame(added_jab3, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab4 = pd.DataFrame(added_jab4, columns=['Nama Prodi', 'Kode Prodi'])

# # # df_added_jab1.head(50)

df_lk = pd.concat([df_lk_temp, df_added_jab1], ignore_index=True)
df_gb = pd.concat([df_gb_temp, df_added_jab2], ignore_index=True)
df_ast = pd.concat([df_ast_temp, df_added_jab3], ignore_index=True)
df_tp = pd.concat([df_tp_temp, df_added_jab4], ignore_index=True)



df_lk.rename(columns = {'Kode Prodi':'Jumlah Lektor Kepala'}, inplace = True)
df_lek.rename(columns = {'Kode Prodi':'Jumlah Lektor'}, inplace = True)
df_gb.rename(columns = {'Kode Prodi':'Jumlah Guru Besar'}, inplace = True)
df_ast.rename(columns = {'Kode Prodi':'Jumlah Asisten Ahli'}, inplace = True)
df_tp.rename(columns = {'Kode Prodi':'Jumlah Tenaga Pengajar'}, inplace = True)

# df_lk.head(100)
df_final_jab1 = (pd.merge(df_lk, df_lek, how='left'))
df_final_jab2 = (pd.merge(df_final_jab1, df_gb, how='left'))
df_final_jab3 = (pd.merge(df_final_jab2, df_ast, how='left'))
df_final_jab = (pd.merge(df_final_jab3, df_tp, how='left'))


df_final_jab["Jumlah"] = df_final_jab["Jumlah Lektor Kepala"] + df_final_jab["Jumlah Lektor"] + df_final_jab["Jumlah Guru Besar"] + df_final_jab["Jumlah Asisten Ahli"] + df_final_jab["Jumlah Tenaga Pengajar"]
df_final_jab["Lektor Kepala"] = ((df_final_jab["Jumlah Lektor Kepala"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Lektor"] = ((df_final_jab["Jumlah Lektor"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Guru Besar"] = ((df_final_jab["Jumlah Guru Besar"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Asisten Ahli"] = ((df_final_jab["Jumlah Asisten Ahli"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Tenaga Pengajar"] = ((df_final_jab["Jumlah Tenaga Pengajar"] / df_final_jab["Jumlah"]) * 100)
df_final_jab = df_final_jab.drop(columns=['Jumlah Lektor Kepala', 'Jumlah Lektor', 'Jumlah Guru Besar', 'Jumlah Asisten Ahli', 
                                  'Jumlah Tenaga Pengajar', 'Jumlah'])

df_final_jab = df_final_jab.sort_values(by="Lektor Kepala", ascending=True)
# df_final_jab.head(20)

plt.rcParams["figure.figsize"] = (10, 8)

df_final_jab.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap3, 
  mark_right = True)
  
df_total_jab = df_final_jab["Lektor Kepala"] + df_final_jab["Lektor"] + df_final_jab["Guru Besar"] + df_final_jab["Asisten Ahli"] + df_final_jab["Tenaga Pengajar"]
df_rel_jab = df_final_jab[df_final_jab.columns[1:]].div(df_total_jab, 0) * 100

for n in df_rel_jab:
    for i, (cs, ab, pc) in enumerate(zip(df_final_jab.iloc[:, 1:].cumsum(1)[n], 
                                         df_final_jab[n], df_rel_jab[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='white')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional untuk Jenjang S1", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S2 dan S3")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah dosen Lektor Kepala', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ## Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional untuk Jenjang S2 dan S3

# %%
temp_lk = df_concat1[df_concat1['Jabatan Fungsional'] == 'Lektor Kepala']
temp_lek = df_concat1[df_concat1['Jabatan Fungsional'] == 'Lektor']
temp_gb = df_concat1[df_concat1['Jabatan Fungsional'] == 'Guru Besar']
temp_ast = df_concat1[df_concat1['Jabatan Fungsional'] == 'Asisten Ahli']
temp_tp = df_concat1[df_concat1['Jabatan Fungsional'] == 'Tenaga Pengajar']

# temp_lk['Kode Prodi'] = temp_lk['Kode Prodi'].fillna(0)
# temp_lk.fillna(0)

# temp_lek.head(100)
df_lk_temp = temp_lk.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_lek_temp = temp_lek.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_gb_temp = temp_gb.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_ast_temp = temp_ast.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()
df_tp_temp = temp_tp.groupby(['Nama Prodi'])['Kode Prodi'].count().reset_index()

# df_tp_temp.head(200)

# df_lk_temp['Kode Prodi'] = df_lk_temp['Kode Prodi'].fillna(0)

added_jab1 = [['Pendidikan Dasar (S3)', 0]]
added_jab2 = [['Kimia (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0],
             ['Pendidikan Kimia (S2)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_jab3 = [['Kimia (S2)', 0], ['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0], ['Pendidikan Kimia (S2)', 0], ['Pendidikan Ilmu Komputer (S2)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]
added_jab4 = [['Kimia (S2)', 0], ['Pendidikan Biologi (S2)', 0], ['Pendidikan Fisika (S2)', 0], ['Pendidikan Matematika (S2)', 0], ['Pendidikan Ilmu Pengetahuan Alam (S3)', 0],
             ['Pendidikan Ilmu Pengetahuan Alam (S2)', 0], ['Pendidikan Kimia (S2)', 0], ['Pendidikan Ilmu Komputer (S2)', 0], ['Pendidikan Dasar (S3)', 0], ['Pendidikan Matematika (S3)', 0]]

df_added_jab1 = pd.DataFrame(added_jab1, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab2 = pd.DataFrame(added_jab2, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab3 = pd.DataFrame(added_jab3, columns=['Nama Prodi', 'Kode Prodi'])
df_added_jab4 = pd.DataFrame(added_jab4, columns=['Nama Prodi', 'Kode Prodi'])

# df_added_jab2.head(50)

df_lk = pd.concat([df_lk_temp, df_added_jab1], ignore_index=True)
df_lek = pd.concat([df_lek_temp, df_added_jab2], ignore_index=True)
df_gb = df_gb_temp
df_ast = pd.concat([df_ast_temp, df_added_jab3], ignore_index=True)
df_tp = pd.concat([df_tp_temp, df_added_jab4], ignore_index=True)

# df_gb.head(20)

df_lk.rename(columns = {'Kode Prodi':'Jumlah Lektor Kepala'}, inplace = True)
df_lek.rename(columns = {'Kode Prodi':'Jumlah Lektor'}, inplace = True)
df_gb.rename(columns = {'Kode Prodi':'Jumlah Guru Besar'}, inplace = True)
df_ast.rename(columns = {'Kode Prodi':'Jumlah Asisten Ahli'}, inplace = True)
df_tp.rename(columns = {'Kode Prodi':'Jumlah Tenaga Pengajar'}, inplace = True)

# # df_lk.head(100)
df_final_jab1 = (pd.merge(df_lk, df_lek, how='left'))
df_final_jab2 = (pd.merge(df_final_jab1, df_gb, how='left'))
df_final_jab3 = (pd.merge(df_final_jab2, df_ast, how='left'))
df_final_jab = (pd.merge(df_final_jab3, df_tp, how='left'))


df_final_jab["Jumlah"] = df_final_jab["Jumlah Lektor Kepala"] + df_final_jab["Jumlah Lektor"] + df_final_jab["Jumlah Guru Besar"] + df_final_jab["Jumlah Asisten Ahli"] + df_final_jab["Jumlah Tenaga Pengajar"]
df_final_jab["Lektor Kepala"] = ((df_final_jab["Jumlah Lektor Kepala"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Lektor"] = ((df_final_jab["Jumlah Lektor"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Guru Besar"] = ((df_final_jab["Jumlah Guru Besar"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Asisten Ahli"] = ((df_final_jab["Jumlah Asisten Ahli"] / df_final_jab["Jumlah"]) * 100)
df_final_jab["Tenaga Pengajar"] = ((df_final_jab["Jumlah Tenaga Pengajar"] / df_final_jab["Jumlah"]) * 100)
df_final_jab = df_final_jab.drop(columns=['Jumlah Lektor Kepala', 'Jumlah Lektor', 'Jumlah Guru Besar', 'Jumlah Asisten Ahli', 
                                  'Jumlah Tenaga Pengajar', 'Jumlah'])

df_final_jab = df_final_jab.sort_values(by="Lektor Kepala", ascending=True)
# # df_final_jab.head(20)

plt.rcParams["figure.figsize"] = (10, 8)

df_final_jab.plot(
  x = 'Nama Prodi', width=0.7,
  kind = 'barh', 
  stacked = True, cmap=custom_cmap3, 
  mark_right = True)
  
df_total_jab = df_final_jab["Lektor Kepala"] + df_final_jab["Lektor"] + df_final_jab["Guru Besar"] + df_final_jab["Asisten Ahli"] + df_final_jab["Tenaga Pengajar"]
df_rel_jab = df_final_jab[df_final_jab.columns[1:]].div(df_total_jab, 0) * 100
  
    
for n in df_rel_jab:
    for i, (cs, ab, pc) in enumerate(zip(df_final_jab.iloc[:, 1:].cumsum(1)[n], 
                                         df_final_jab[n], df_rel_jab[n])):
        if pc != 0:
            plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', rotation = 10, fontsize = 12, color='white')
plt.title("Perbandingan Persentase Jumlah Dosen FPMIPA Berdasarkan Jabatan Fungsional untuk Jenjang S2 dan S3", size=14, y=1.05)
plt.xlabel("Persentase Jumlah Dosen")
plt.ylabel("Program Studi S2 dan S3")

plt.text(0,-2.4,'Diurutkan berdasarkan persentase jumlah dosen Lektor Kepala', fontstyle="normal", fontweight="normal")
plt.text(0,-2.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
# Out:
# Text(0, -2.8, 'Data Agustus 2022')

# %% [markdown]
# ### Distribusi Usia Dosen FPMIPA

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'Usia'

# %%
df['Usia'].describe()
# Out:
# count    193.000000
# mean      50.564767
# std       10.034171
# min       27.000000
# 25%       43.000000
# 50%       53.000000
# 75%       59.000000
# max       69.000000
# Name: Usia, dtype: float64

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'Usia' Menggunakan Boxplot

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df, x="Usia", showmeans=True)

# %% [markdown]
# ## Distrbusi Usia Dosen FPMIPA berdasarkan Gender

# %%
fig, axes = plt.subplots(1, 2, figsize=(12.6, 4.8))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle("Distribusi Usia Dosen FPMIPA Berdasarkan Gender dan Pendidikan Terakhir"
             , fontsize = 'large', fontweight = 'bold', y=1)

gender = df.groupby('Jenis Kelamin')["Usia"].median().reset_index()
gender = gender.sort_values(by="Usia", ascending=False)

pend_akhir = df.groupby('Pendidikan Terakhir')["Usia"].median().reset_index()
pend_akhir = pend_akhir.sort_values(by="Usia", ascending=False)

gender = sns.boxplot(x ='Usia', y = 'Jenis Kelamin', data = df, order=gender['Jenis Kelamin'], palette=custom_palette1, width=0.70, showmeans=True, ax=axes[0])
pend_akhir = sns.boxplot(x ='Usia', y = 'Pendidikan Terakhir', data = df, order=pend_akhir['Pendidikan Terakhir'], palette='mako', width=0.70, showmeans=True, ax=axes[1])


gender.set_title('Berdasarkan Gender',fontweight="normal", size=13, y=1.05)
gender.set_xlabel('Usia', fontsize = 12)
gender.set_ylabel('Gender')


pend_akhir.set_title('Berdasarkan Pendidikan Terakhir',fontweight="normal", size=13, y=1.05)
pend_akhir.set_xlabel('Usia', fontsize = 12)
pend_akhir.set_ylabel('Pendidikan Terakhir')

gender.text(25, 2.2,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
gender.text(25, 2.4,'Diurutkan berdasarkan median', fontstyle="normal")
pend_akhir.text(26, 2.2,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")
pend_akhir.text(26, 2.4,'Diurutkan berdasarkan median', fontstyle="normal")

plt.show()

# %% [markdown]
# ### Distribusi Usia Dosen FPMIPA Berdasarkan Golongan

# %%
plt.figure(figsize=(10, 6.8))

# prodi = df_topten_scopus
gol = df.groupby('Gol')["Usia"].median().reset_index()
gol = gol.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Gol', data = df, order=gol['Gol'], palette="deep", width=0.70, showmeans=True)

g.set(xlabel='Usia', ylabel='Golongan')
g.text(25, 10.2,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(25, 10.6,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi Usia Dosen FPMIPA Berdasarkan Golongan" , y=1, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi Usia Dosen FPMIPA Berdasarkan Jabatan Fungsional

# %%
plt.figure(figsize=(10, 4))

jab_fung = df.groupby('Jabatan Fungsional')["Usia"].median().reset_index()
jab_fung = jab_fung.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Jabatan Fungsional', data = df, palette="deep", order=jab_fung['Jabatan Fungsional'], width=0.70, showmeans=True)

g.set(xlabel='Usia', ylabel='Jabatan Fungsional')
g.text(25, 6.1,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(25, 6.5,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi Usia Dosen FPMIPA Berdasarkan Jabatan Fungsional" , y=1, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Setiap Jenjang S1, S2, dan S3 Berdasarkan Gender dan Pendidikan Terakhir

# %%
df_s1 = df[df["Nama Prodi"].str.contains("S1") == True]
df_s2 = df[df["Nama Prodi"].str.contains("S2") == True]
df_s3 = df[df["Nama Prodi"].str.contains("S3") == True]

fig, axes = plt.subplots(1, 3, figsize=(16, 5.5))
fig.tight_layout()
fig.tight_layout(pad=5)


fig.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Setiap Jenjang S1, S2, dan S3 Berdasarkan Gender "
             , fontsize = 'large', fontweight = 'bold', y=1)

s1 = sns.histplot(df_s1, x="Usia", hue="Jenis Kelamin", multiple='stack', palette=custom_palette1, ax=axes[0])
s2 = sns.histplot(df_s2, x="Usia", hue="Jenis Kelamin", multiple='stack', palette=custom_palette1, ax=axes[1])
s3 = sns.histplot(df_s3, x="Usia", hue="Jenis Kelamin", multiple='stack', palette=custom_palette1, ax=axes[2])

s1.set_title('Sarjana (S1)',fontweight="normal", size=13, y=1.05)
s1.set_xlabel('Usia', fontsize = 12)
s1.set_ylabel('Jumlah Dosen')


s2.set_title('Magister (S2)',fontweight="normal", size=13, y=1.05)
s2.set_xlabel('Usia', fontsize = 12)
s2.set_ylabel('Jumlah Dosen')

s3.set_title('Doktor (S3)',fontweight="normal", size=13, y=1.05)
s3.set_xlabel('Usia', fontsize = 12)
s3.set_ylabel('Jumlah Dosen')

fig, axes = plt.subplots(1, 3, figsize=(16, 5.5))
fig.tight_layout()
fig.tight_layout(pad=5)


fig.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Setiap Jenjang S1, S2, dan S3 Berdasarkan Pendidikan Terakhir"
             , fontsize = 'large', fontweight = 'bold', y=1)

s1_2 = sns.histplot(df_s1, x="Usia", hue="Pendidikan Terakhir", multiple='stack', palette="mako", ax=axes[0])
s2_2 = sns.histplot(df_s2, x="Usia", hue="Pendidikan Terakhir", multiple='stack', palette="mako", ax=axes[1])
s3_2 = sns.histplot(df_s3, x="Usia", hue="Pendidikan Terakhir", multiple='stack', palette="mako", ax=axes[2])

s1_2.set_title('Sarjana (S1)',fontweight="normal", size=13, y=1.05)
s1_2.set_xlabel('Usia', fontsize = 12)
s1_2.set_ylabel('Jumlah Dosen')


s2_2.set_title('Magister (S2)',fontweight="normal", size=13, y=1.05)
s2_2.set_xlabel('Usia', fontsize = 12)
s2_2.set_ylabel('Jumlah Dosen')

s3_2.set_title('Doktor (S3)',fontweight="normal", size=13, y=1.05)
s3_2.set_xlabel('Usia', fontsize = 12)
s3_2.set_ylabel('Jumlah Dosen')

s1_2.text(25,-6,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

# tampilkan value 
for container in s1.containers:
    s1.bar_label(container, padding=2)
for container in s2.containers:
    s2.bar_label(container, padding=2)
for container in s3.containers:
    s3.bar_label(container, padding=2)
for container in s1_2.containers:
    s1_2.bar_label(container, padding=2)
for container in s2_2.containers:
    s2_2.bar_label(container, padding=2)
for container in s3_2.containers:
    s3_2.bar_label(container, padding=2)

plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1

# %%
plt.figure(figsize=(12, 6))

# prodi = df_topten_scopus
prodis1 = df_s1.groupby('Nama Prodi')["Usia"].mean().reset_index()
prodi_s1 = prodis1.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Nama Prodi', data = df_s1, palette="deep", order = prodi_s1['Nama Prodi'], width=0.70, showmeans=True)

g.set(xlabel='Usia', ylabel='Program Studi S1')
g.text(25, 12,'Diurutkan berdasarkan rata-rata', fontstyle="normal")
g.text(25, 12.5,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1" , y=1, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1 Berdasarkan Gender

# %%
plt.figure(figsize=(12, 10))

# prodi = df_topten_scopus
prodis1 = df_s1.groupby('Nama Prodi')["Usia"].mean().reset_index()
prodi_s1 = prodis1.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Nama Prodi', hue='Jenis Kelamin', data = df_s1, palette=custom_palette1, order = prodi_s1['Nama Prodi'], width=0.74, showmeans=True)

g.set(xlabel='Usia', ylabel='Program Studi S1')
g.text(25, 12,'Diurutkan berdasarkan rata-rata', fontstyle="normal")
g.text(25, 12.3,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1 Berdasarkan Gender" , y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1 Berdasarkan Pendidikan Terakhir

# %%
plt.figure(figsize=(12, 10))

# prodi = df_topten_scopus
prodis1 = df_s1.groupby('Nama Prodi')["Usia"].mean().reset_index()
prodi_s1 = prodis1.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Nama Prodi', hue='Pendidikan Terakhir', data = df_s1, palette="mako", order = prodi_s1['Nama Prodi'], width=0.8, showmeans=True)

g.set(xlabel='Usia', ylabel='Program Studi S1')
g.text(25, 12,'Diurutkan berdasarkan rata-rata', fontstyle="normal")
g.text(25, 12.3,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S1 Berdasarkan Pendidikan Terakhir" , y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S2, S3, dan Profesi

# %%
plt.figure(figsize=(12, 6))
# df_concat2.head(400)

# # prodi = df_topten_scopus
prodis2 = df_concat1.groupby('Nama Prodi')["Usia"].mean().reset_index()
prodi_s2 = prodis2.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Nama Prodi', data = df_concat1, palette="deep", order = prodi_s2['Nama Prodi'], width=0.68, showmeans=True)

g.set(xlabel='Usia', ylabel='Program Studi S2, S3, dan Profesi')
g.text(38, 12.5,'Diurutkan berdasarkan rata-rata', fontstyle="normal")
g.text(38, 13,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S2, S3, dan Profesi" , y=1, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S2, S3, dan Profesi Berdasarkan Gender

# %%
plt.figure(figsize=(12, 8))

# df_profesi = df[df["Nama Prodi"].str.contains("Profesi") == True]

df_concat1 = pd.concat([df_s2, df_s3], ignore_index=True)
# df_concat1 = pd.concat([df_concat1, df_profesi], ignore_index=True)
# df_concat2.head(400)

# # prodi = df_topten_scopus
prodis2 = df_concat1.groupby('Nama Prodi')["Usia"].mean().reset_index()
prodi_s2 = prodis2.sort_values(by="Usia", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='Usia', y = 'Nama Prodi', hue='Jenis Kelamin', data = df_concat1, palette=custom_palette1, order = prodi_s2['Nama Prodi'], width=1, showmeans=True)

g.set(xlabel='Usia', ylabel='Program Studi S2, S3, dan Profesi')
g.text(38, 12.1,'Diurutkan berdasarkan rata-rata', fontstyle="normal")
g.text(38, 12.6,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Perbandingan Distribusi Usia Dosen FPMIPA untuk Jenjang S2, S3, dan Profesi Berdasarkan Gender" , y=0.94, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Perbandingan Distribusi H indeks pada Scopus, Google Scholar, dan Web of Science FPMIPA

# %%
df_sort_gs = df.sort_values(by="gs_h_index", ascending=False)
df_sort_wos = df.sort_values(by="wos_h_index", ascending=False)

n = 10
m = 5
df_topten1 = df_sort_gs.head(int(len(df_sort_gs)*(n/100)))
df_topten2 = df_sort_wos.head(int(len(df_sort_wos)*(m/100)))
df_final1 = list(df_topten1.nama.values)
df_final2 = list(df_topten2.nama.values)

df_topten_gs = df[~df.nama.isin(df_final1)]
df_topten_wos = df[~df.nama.isin(df_final2)]

df_sort_scopus_hindex = df.sort_values(by="scopus_h_index", ascending=False)

n = 10
df_topten = df_sort_scopus_hindex.head(int(len(df_sort_scopus_hindex)*(n/100)))
df_final = list(df_topten.nama.values)

df_topten_scopus = df[~df.nama.isin(df_final)]
# df_topten_scopus['nama'].iat[556]

    
fig, axes = plt.subplots(1, 3, figsize=(14, 3.5))
fig.tight_layout()
fig.tight_layout(pad=3)
fig.suptitle("Perbandingan Distribusi H Indeks pada Scopus, Google Scholar, dan Web of Science" , fontsize = 'large', fontweight = 'bold', y=1.05)


scopus = sns.boxplot(x='scopus_h_index', data = df_topten_scopus, palette="deep", showmeans=True, ax=axes[0])
gs = sns.boxplot(x='gs_h_index', data = df_topten_gs, palette="deep", showmeans=True, ax=axes[1])
wos = sns.boxplot(x='wos_h_index', data = df_topten_wos, palette="deep", showmeans=True, ax=axes[2])


scopus.set_title('Distribusi Scopus H Index',fontweight="normal", size=13)
scopus.set_xlabel('Scopus H Index', fontsize = 12)
scopus.set_ylabel('')

gs.set_title('Distribusi Google Scholar H Index',fontweight="normal", size=13)
gs.set_xlabel('Google Scholar H Index', fontsize = 12)
gs.set_ylabel('')

wos.set_title('Distribusi WOS H Index',fontweight="normal", size=13)
wos.set_xlabel('WOS H Index', fontsize = 12)
wos.set_ylabel('')

fig, axes = plt.subplots(1, 3, figsize=(13.6, 4))
fig.tight_layout()
fig.tight_layout(pad=3)


scopus = sns.histplot(x='scopus_h_index', data = df_topten_scopus, binwidth=0.9, palette="deep", ax=axes[0])
gs = sns.histplot(x='gs_h_index', data = df_topten_gs, binwidth=2, palette="deep", ax=axes[1])
wos = sns.histplot(x='wos_h_index', data = df_topten_wos,  binwidth=0.8, palette="deep", ax=axes[2])

scopus.set_title('Distribusi Scopus H Index',fontweight="normal", size=13)
scopus.set_xlabel('Scopus H Index', fontsize = 12)
scopus.set_ylabel('')

gs.set_title('Distribusi Google Scholar H Index',fontweight="normal", size=13)
gs.set_xlabel('Google Scholar H Index', fontsize = 12)
gs.set_ylabel('')

wos.set_title('Distribusi WOS H Index',fontweight="normal", size=13)
wos.set_xlabel('WOS H Index', fontsize = 12)
wos.set_ylabel('')

for container in scopus.containers:
    scopus.bar_label(container, padding=2)
for container in gs.containers:
    gs.bar_label(container, padding=2)
for container in wos.containers:
    wos.bar_label(container, padding=2)

plt.show()

# %% [markdown]
# ### 2 Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index

# %%
dosen_muda = df[df["Usia"] <= 30]

top_scopus_hindex_muda = dosen_muda.sort_values(by="scopus_h_index", ascending=False).head(2)
top_gs_hindex_muda = dosen_muda.sort_values(by="gs_h_index", ascending=False).head(5)
top_scopus_article_muda = dosen_muda.sort_values(by="scopus_article", ascending=False).head(3)
top_gs_article_muda = dosen_muda.sort_values(by="gs_article", ascending=False).head(5)


image_scopushindex_muda = top_scopus_hindex_muda[["nama", "Usia", "Nama Prodi", "scopus_h_index"]]
image_scopushindex_muda.reset_index(drop=True, inplace=True)
# image_scopushindex_muda.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1', 'Hafiz Aji Aziz, S.Si., M.Sc.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4', 'Mita Nurhayati, S.Pd., M.Si.']
    ]

# image_scopushindex_muda.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_scopushindex_muda, left_on='nama', right_on='nama', how='left'))

df_test.rename(columns = {'nama':'Nama', 'scopus_h_index':'Scopus H Index', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)
df_test = df_test.astype({'Scopus H Index': 'Int64'})

df_test.index = np.arange(1, len(image_scopushindex_muda)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '2 Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 2 Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Scopus H Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1" width="60" ></td>
#       <td>Hafiz Aji Aziz, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4" width="60" ></td>
#       <td>Mita Nurhayati, S.Pd., M.Si.</td>
#       <td>27</td>
#       <td>Kimia (S1)</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen Muda FPMIPA Teratas Berdasarkan Google Scholar H Index

# %%
image_gshindex_muda = top_gs_hindex_muda[["nama", "Usia", "Nama Prodi", "gs_h_index"]]
image_gshindex_muda.reset_index(drop=True, inplace=True)
image_gshindex_muda.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1', 'Hafiz Aji Aziz, S.Si., M.Sc.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1', 'Vidia Afina Nuraini, S.Si., M.Sc. '],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4', 'Mita Nurhayati, S.Pd., M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ma6n5O0AAAAJ&citpid=7', 'Ani Anisyah, S.Pd., M.T.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=d2yneW4AAAAJ&citpid=1', 'Andini Setya Arianti, S.Ds., M.Ds.'],
    ]

image_gshindex_muda.head()

testt = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_testt = (pd.merge(testt, image_gshindex_muda, left_on='nama', right_on='nama', how='left'))
df_testt = df_testt.astype({'gs_h_index': 'Int64'})
df_testt.rename(columns = {'nama':'Nama', 'gs_h_index':'Google Scholar H Index', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_testt.index = np.arange(1, len(image_gshindex_muda)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen Muda FPMIPA Teratas Berdasarkan Google Scholar H Index' + '\033[0m\n')

df_testt.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_testt.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# Out:
# 5 Dosen Muda FPMIPA Teratas Berdasarkan Google Scholar H Index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Google Scholar H Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1" width="60" ></td>
#       <td>Hafiz Aji Aziz, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1" width="60" ></td>
#       <td>Vidia Afina Nuraini, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4" width="60" ></td>
#       <td>Mita Nurhayati, S.Pd., M.Si.</td>
#       <td>27</td>
#       <td>Kimia (S1)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ma6n5O0AAAAJ&citpid=7" width="60" ></td>
#       <td>Ani Anisyah, S.Pd., M.T.</td>
#       <td>29</td>
#       <td>Ilmu Komputer (S1)</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=d2yneW4AAAAJ&citpid=1" width="60" ></td>
#       <td>Andini Setya Arianti, S.Ds., M.Ds.</td>
#       <td>27</td>
#       <td>Pendidikan Ilmu Komputer (S1)</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus

# %%
image_scopusarticle_muda = top_scopus_article_muda[["nama", "Usia", "Nama Prodi", "scopus_article"]]
image_scopusarticle_muda.reset_index(drop=True, inplace=True)
image_scopusarticle_muda.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1', 'Hafiz Aji Aziz, S.Si., M.Sc.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4', 'Mita Nurhayati, S.Pd., M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1', 'Vidia Afina Nuraini, S.Si., M.Sc. '],
    ]

image_scopusarticle_muda.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_scopusarticle_muda, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'scopus_article': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'scopus_article':'Jumlah Artikel Scopus', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_scopusarticle_muda)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '3 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 3 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Jumlah Artikel Scopus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1" width="60" ></td>
#       <td>Hafiz Aji Aziz, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4" width="60" ></td>
#       <td>Mita Nurhayati, S.Pd., M.Si.</td>
#       <td>27</td>
#       <td>Kimia (S1)</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1" width="60" ></td>
#       <td>Vidia Afina Nuraini, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar

# %%
image_gsarticle_muda = top_gs_article_muda[["nama", "Usia", "Nama Prodi", "gs_article"]]
image_gsarticle_muda.reset_index(drop=True, inplace=True)
image_gsarticle_muda.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1', 'Hafiz Aji Aziz, S.Si., M.Sc.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4', 'Mita Nurhayati, S.Pd., M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=d2yneW4AAAAJ&citpid=1', 'Andini Setya Arianti, S.Ds., M.Ds.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1', 'Vidia Afina Nuraini, S.Si., M.Sc. '],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=DVSBmk8AAAAJ&citpid=2', 'Abraham Mora, M.Si. '],
    ]

# image_gsarticle_muda.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_gsarticle_muda, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'gs_article': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'gs_article':'Jumlah Artikel Google Scholar', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_gsarticle_muda)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 5 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Jumlah Artikel Google Scholar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=R0Fi-UIAAAAJ&citpid=1" width="60" ></td>
#       <td>Hafiz Aji Aziz, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=1tY88b0AAAAJ&citpid=4" width="60" ></td>
#       <td>Mita Nurhayati, S.Pd., M.Si.</td>
#       <td>27</td>
#       <td>Kimia (S1)</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=d2yneW4AAAAJ&citpid=1" width="60" ></td>
#       <td>Andini Setya Arianti, S.Ds., M.Ds.</td>
#       <td>27</td>
#       <td>Pendidikan Ilmu Komputer (S1)</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=E-tnT-oAAAAJ&citpid=1" width="60" ></td>
#       <td>Vidia Afina Nuraini, S.Si., M.Sc.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=DVSBmk8AAAAJ&citpid=2" width="60" ></td>
#       <td>Abraham Mora, M.Si.</td>
#       <td>29</td>
#       <td>Kimia (S1)</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index, Google Scholar H Index, Jumlah Artikel Scopus dan Google Scholar

# %%
dosen_muda = df[df["Usia"] <= 30]

top_scopus_hindex_muda = dosen_muda.sort_values(by="scopus_h_index", ascending=False).head(2)
top_gs_hindex_muda = dosen_muda.sort_values(by="gs_h_index", ascending=False).head(5)
top_scopus_article_muda = dosen_muda.sort_values(by="scopus_article", ascending=False).head(3)
top_gs_article_muda = dosen_muda.sort_values(by="gs_article", ascending=False).head(5)

fig, axes = plt.subplots(4, 1, figsize=(10, 12))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle("5 Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index, Google Scholar H Index, Jumlah Artikel Scopus dan Jumlah Artikel Google Scholar"
             , fontsize = 'large', fontweight = 'bold', y=1)

scopus_hindex = sns.barplot(x='scopus_h_index', y='nama', data = top_scopus_hindex_muda, palette="deep", ax=axes[0])
gs_hindex = sns.barplot(x='gs_h_index', y='nama', data = top_gs_hindex_muda, palette="deep", ax=axes[1])
scopus_article = sns.barplot(x='scopus_article', y='nama', data = top_scopus_article_muda, palette="deep", ax=axes[2])
gs_article = sns.barplot(x='gs_article', y='nama', data = top_gs_article_muda, palette="deep", ax=axes[3])

scopus_hindex.set_title('2 Dosen Muda FPMIPA Teratas Berdasarkan Scopus H Index',fontweight="bold", size=13)
scopus_hindex.set_xlabel('Scopus H Index', fontsize = 12)
scopus_hindex.set_ylabel('')


gs_hindex.set_title('5 Dosen Muda FPMIPA Teratas Berdasarkan Google Scholar Index',fontweight="bold", size=13)
gs_hindex.set_xlabel('Google Scholar H Index', fontsize = 12)
gs_hindex.set_ylabel('')


scopus_article.set_title('3 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus',fontweight="bold", size=13)
scopus_article.set_xlabel('Jumlah Artikel Scopus', fontsize = 12)
scopus_article.set_ylabel('')

gs_article.set_title('5 Dosen Muda FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar',fontweight="bold", size=13)
gs_article.set_xlabel('Jumlah Artikel Google Scholar', fontsize = 12)
gs_article.set_ylabel('')

gs_article.text(0.1,7.5,'Dosen Muda : dosen yang saat ini berusia kurang dari atau sama dengan 30 tahun', fontstyle="normal")
gs_article.text(0.1,8.1,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

for container in scopus_hindex.containers:
    scopus_hindex.bar_label(container, padding=4)
for container in gs_hindex.containers:
    gs_hindex.bar_label(container, padding=4)
for container in scopus_article.containers:
    scopus_article.bar_label(container, padding=4)
for container in gs_article.containers:
    gs_article.bar_label(container, padding=4)

plt.show()

# %% [markdown]
# ### 5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index

# %%
top_scopus_hindex = df.sort_values(by="scopus_h_index", ascending=False).head(5)
top_gs_hindex = df.sort_values(by="gs_h_index", ascending=False).head(5)
top_scopus_article = df.sort_values(by="scopus_article", ascending=False).head(5)
top_gs_article = df.sort_values(by="gs_article", ascending=False).head(5)

image_scopushindex = top_scopus_hindex[["nama", "Usia", "Nama Prodi", "scopus_h_index"]]
image_scopushindex.reset_index(drop=True, inplace=True)
image_scopushindex.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2', 'Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17', 'Dr. Achmad Samsudin, M.Pd.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=3gzoyMgAAAAJ&citpid=2', 'Heli Siti Halimatul Munawaroh, M.Si., Ph.D., Sc.'],
    ['https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2', 'Prof. Dr. Andi Suhandi, M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4', 'Dr. Ida Kaniawati, M.Si.'],
    ]

image_scopushindex.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_scopushindex, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'scopus_h_index': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'scopus_h_index':'Scopus H Index', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_scopushindex)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Scopus H Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2" width="60" ></td>
#       <td>Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.</td>
#       <td>39</td>
#       <td>Kimia (S2)</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17" width="60" ></td>
#       <td>Dr. Achmad Samsudin, M.Pd.</td>
#       <td>38</td>
#       <td>Pendidikan Fisika (S1)</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=3gzoyMgAAAAJ&citpid=2" width="60" ></td>
#       <td>Heli Siti Halimatul Munawaroh, M.Si., Ph.D., Sc.</td>
#       <td>43</td>
#       <td>Kimia (S2)</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2" width="60" ></td>
#       <td>Prof. Dr. Andi Suhandi, M.Si.</td>
#       <td>53</td>
#       <td>Pendidikan Fisika (S2)</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4" width="60" ></td>
#       <td>Dr. Ida Kaniawati, M.Si.</td>
#       <td>54</td>
#       <td>Pendidikan Ilmu Pengetahuan Alam (S3)</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen FPMIPA Teratas Berdasarkan Google Scholar H Index

# %%
image_gshindex = top_gs_hindex[["nama", "Usia", "Nama Prodi", "gs_h_index"]]
image_gshindex.reset_index(drop=True, inplace=True)
image_gshindex.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2', 'Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17', 'Dr. Achmad Samsudin, M.Pd.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=diiZoeIAAAAJ&citpid=2', 'Prof. H. Yaya Sukjaya Kusumah, M.Sc., Ph.D.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3', 'Prof. Dr. H. Didi Suryadi, M.Ed.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4', 'Dr. Ida Kaniawati, M.Si.'],
    ]

image_gshindex.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_gshindex, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'gs_h_index': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'gs_h_index':'Google Scholar H Index', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_gshindex)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen FPMIPA Teratas Berdasarkan Google Scholar H Index' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 5 Dosen FPMIPA Teratas Berdasarkan Google Scholar H Index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Google Scholar H Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2" width="60" ></td>
#       <td>Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.</td>
#       <td>39</td>
#       <td>Kimia (S2)</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17" width="60" ></td>
#       <td>Dr. Achmad Samsudin, M.Pd.</td>
#       <td>38</td>
#       <td>Pendidikan Fisika (S1)</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=diiZoeIAAAAJ&citpid=2" width="60" ></td>
#       <td>Prof. H. Yaya Sukjaya Kusumah, M.Sc., Ph.D.</td>
#       <td>63</td>
#       <td>Pendidikan Matematika (S3)</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3" width="60" ></td>
#       <td>Prof. Dr. H. Didi Suryadi, M.Ed.</td>
#       <td>64</td>
#       <td>Pendidikan Matematika (S3)</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4" width="60" ></td>
#       <td>Dr. Ida Kaniawati, M.Si.</td>
#       <td>54</td>
#       <td>Pendidikan Ilmu Pengetahuan Alam (S3)</td>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus

# %%
image_scopusarticle = top_scopus_article[["nama", "Usia", "Nama Prodi", "scopus_article"]]
image_scopusarticle.reset_index(drop=True, inplace=True)
image_scopusarticle.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2', 'Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17', 'Dr. Achmad Samsudin, M.Pd.'],
    ['https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2', 'Prof. Dr. Andi Suhandi, M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3', 'Prof. Dr. H. Didi Suryadi, M.Ed.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4', 'Dr. Ida Kaniawati, M.Si.'],
    ]

image_scopusarticle.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_scopusarticle, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'scopus_article': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'scopus_article':'Jumlah Artikel Scopus', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_scopusarticle)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Scopus
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Jumlah Artikel Scopus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2" width="60" ></td>
#       <td>Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.</td>
#       <td>39</td>
#       <td>Kimia (S2)</td>
#       <td>296</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17" width="60" ></td>
#       <td>Dr. Achmad Samsudin, M.Pd.</td>
#       <td>38</td>
#       <td>Pendidikan Fisika (S1)</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2" width="60" ></td>
#       <td>Prof. Dr. Andi Suhandi, M.Si.</td>
#       <td>53</td>
#       <td>Pendidikan Fisika (S2)</td>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3" width="60" ></td>
#       <td>Prof. Dr. H. Didi Suryadi, M.Ed.</td>
#       <td>64</td>
#       <td>Pendidikan Matematika (S3)</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=x2kArokAAAAJ&citpid=4" width="60" ></td>
#       <td>Dr. Ida Kaniawati, M.Si.</td>
#       <td>54</td>
#       <td>Pendidikan Ilmu Pengetahuan Alam (S3)</td>
#       <td>96</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar

# %%
image_gsarticle = top_gs_article[["nama", "Usia", "Nama Prodi", "gs_article"]]
image_gsarticle.reset_index(drop=True, inplace=True)
image_gsarticle.head()

image_link = [
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2', 'Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17', 'Dr. Achmad Samsudin, M.Pd.'],
    ['https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2', 'Prof. Dr. Andi Suhandi, M.Si.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=6g4ETNsAAAAJ&citpid=2', 'Prof. Dr. Phil. H. Ari Widodo, M.Ed.'],
    ['https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3', 'Prof. Dr. H. Didi Suryadi, M.Ed.'],
    ]

image_gsarticle.head()

test = pd.DataFrame(image_link, columns =['Foto', 'nama'])

df_test = (pd.merge(test, image_gsarticle, left_on='nama', right_on='nama', how='left'))
df_test = df_test.astype({'gs_article': 'Int64'})
df_test.rename(columns = {'nama':'Nama', 'gs_article':'Jumlah Artikel Google Scholar', 'Nama Prodi':'Program Studi', 'Jenis Kelamin':'Gender'}, inplace = True)


df_test.index = np.arange(1, len(image_gsarticle)+1)

def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

print('\033[1m' + '5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar' + '\033[0m\n')

df_test.to_html(escape=False, formatters=dict(Foto=path_to_image_html))
HTML(df_test.to_html(classes = "", escape=False,formatters=dict(Foto=path_to_image_html)))
# image_scopushindex_muda.to_html('webpage.html',escape=False, formatters=dict(Image=path_to_image_html))
# Out:
# 5 Dosen FPMIPA Teratas Berdasarkan Jumlah Artikel Google Scholar
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Foto</th>
#       <th>Nama</th>
#       <th>Usia</th>
#       <th>Program Studi</th>
#       <th>Jumlah Artikel Google Scholar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=pUODwOIAAAAJ&citpid=2" width="60" ></td>
#       <td>Dr. Eng. Asep Bayu Dani Nandiyanto, S.T., M.Eng.</td>
#       <td>39</td>
#       <td>Kimia (S2)</td>
#       <td>477</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=twHQXSIAAAAJ&citpid=17" width="60" ></td>
#       <td>Dr. Achmad Samsudin, M.Pd.</td>
#       <td>38</td>
#       <td>Pendidikan Fisika (S1)</td>
#       <td>347</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=medium_photo&user=C5ZhMRIAAAAJ&citpid=2" width="60" ></td>
#       <td>Prof. Dr. Andi Suhandi, M.Si.</td>
#       <td>53</td>
#       <td>Pendidikan Fisika (S2)</td>
#       <td>334</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=6g4ETNsAAAAJ&citpid=2" width="60" ></td>
#       <td>Prof. Dr. Phil. H. Ari Widodo, M.Ed.</td>
#       <td>55</td>
#       <td>Pendidikan Ilmu Pengetahuan Alam (S2)</td>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://scholar.googleusercontent.com/citations?view_op=view_photo&user=Ea4oF0EAAAAJ&citpid=3" width="60" ></td>
#       <td>Prof. Dr. H. Didi Suryadi, M.Ed.</td>
#       <td>64</td>
#       <td>Pendidikan Matematika (S3)</td>
#       <td>258</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index, Google Scholar H Index, Jumlah Artikel Scopus dan Google Scholar

# %%
fig, axes = plt.subplots(4, 1, figsize=(10, 12))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle("5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index, Google Scholar H Index, Jumlah Artikel Scopus dan Jumlah Artikel Google Scholar"
             , fontsize = 'large', fontweight = 'bold', y=1)

scopus_hindex = sns.barplot(x='scopus_h_index', y='nama', data = top_scopus_hindex, palette="deep", ax=axes[0])
gs_hindex = sns.barplot(x='gs_h_index', y='nama', data = top_gs_hindex, palette="deep", ax=axes[1])
scopus_article = sns.barplot(x='scopus_article', y='nama', data = top_scopus_article, palette="deep", ax=axes[2])
gs_article = sns.barplot(x='gs_article', y='nama', data = top_gs_article, palette="deep", ax=axes[3])


scopus_hindex.set_title('5 Dosen FPMIPA Teratas Berdasarkan Scopus H Index',fontweight="bold", size=13)
scopus_hindex.set_xlabel('Scopus H Index', fontsize = 12)
scopus_hindex.set_ylabel('')

gs_hindex.set_title('5 Dosen FPMIPA Teratas Berdasarkan Google Scholar Index',fontweight="bold", size=13)
gs_hindex.set_xlabel('Google Scholar H Index', fontsize = 12)
gs_hindex.set_ylabel('')

scopus_article.set_title('5 FPMIPA Dosen Teratas Berdasarkan Jumlah Artikel Scopus',fontweight="bold", size=13)
scopus_article.set_xlabel('Jumlah Artikel Scopus', fontsize = 12)
scopus_article.set_ylabel('')

gs_article.set_title('5 FPMIPA Dosen Teratas Berdasarkan Jumlah Artikel Google Scholar',fontweight="bold", size=13)
gs_article.set_xlabel('Jumlah Artikel Google Scholar', fontsize = 12)
gs_article.set_ylabel('')

gs_article.text(0,7.1,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

for container in scopus_hindex.containers:
    scopus_hindex.bar_label(container, padding=4)
for container in gs_hindex.containers:
    gs_hindex.bar_label(container, padding=4)
for container in scopus_article.containers:
    scopus_article.bar_label(container, padding=4)
for container in gs_article.containers:
    gs_article.bar_label(container, padding=4)

plt.show()

# %% [markdown]
# ### 5 Program Studi FPMIPA Teratas Berdasarkan Median dan Mean pada Scopus H Index dan Google Scholar H Index untuk Jenjang S1

# %%
fakul_hindex = df_s1

df_fakul_scopushindex_median = fakul_hindex.groupby('Nama Prodi')["scopus_h_index"].median().reset_index()
df_fakul_gshindex_median = fakul_hindex.groupby('Nama Prodi')["gs_h_index"].median().reset_index()

df_fakul_scopushindex_mean = fakul_hindex.groupby('Nama Prodi')["scopus_h_index"].mean().reset_index()
df_fakul_gshindex_mean = fakul_hindex.groupby('Nama Prodi')["gs_h_index"].mean().reset_index()


top_fakul_scopus_hindex_median = df_fakul_scopushindex_median.sort_values(by="scopus_h_index", ascending=False).head(5)
top_fakul_gs_hindex_median = df_fakul_gshindex_median.sort_values(by="gs_h_index", ascending=False).head(5)
top_fakul_scopus_hindex_mean = df_fakul_scopushindex_mean.sort_values(by="scopus_h_index", ascending=False).head(5)
top_fakul_gs_hindex_mean = df_fakul_gshindex_mean.sort_values(by="gs_h_index", ascending=False).head(5)


fig, axes = plt.subplots(4, 1, figsize=(10, 12))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle("5 Program Studi FPMIPA Teratas Berdasarkan Median dan Mean pada Scopus H Index dan Google Scholar H Index untuk Jenjang S1"
             , fontsize = 'large', fontweight = 'bold', y=1)

fakul_scopus_hindex_median = sns.barplot(x='scopus_h_index', y='Nama Prodi', data = top_fakul_scopus_hindex_median, palette="deep", ax=axes[0])
fakul_gs_hindex_median = sns.barplot(x='gs_h_index', y='Nama Prodi', data = top_fakul_gs_hindex_median, palette="deep", ax=axes[1])
fakul_scopus_hindex_mean = sns.barplot(x='scopus_h_index', y='Nama Prodi', data = top_fakul_scopus_hindex_mean, palette="deep", ax=axes[2])
fakul_gs_hindex_mean = sns.barplot(x='gs_h_index', y='Nama Prodi', data = top_fakul_gs_hindex_mean, palette="deep", ax=axes[3])

fakul_scopus_hindex_median.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Median Scopus H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_scopus_hindex_median.set_xlabel('Median Scopus H Index', fontsize = 12)
fakul_scopus_hindex_median.set_ylabel('')

fakul_gs_hindex_median.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Median Google Scholar H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_gs_hindex_median.set_xlabel('Median Google Scholar H Index', fontsize = 12)
fakul_gs_hindex_median.set_ylabel('')

fakul_scopus_hindex_mean.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Rata-rata Scopus H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_scopus_hindex_mean.set_xlabel('Rata-rata Scopus H Index', fontsize = 12)
fakul_scopus_hindex_mean.set_ylabel('')

fakul_gs_hindex_mean.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Rata-rata Google Scholar H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_gs_hindex_mean.set_xlabel('Rata-rata Google Scholar H Index', fontsize = 12)
fakul_gs_hindex_mean.set_ylabel('')


fakul_gs_hindex_mean.text(0.1,7.5,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

for container in fakul_scopus_hindex_median.containers:
    fakul_scopus_hindex_median.bar_label(container, padding=4)
for container in fakul_gs_hindex_median.containers:
    fakul_gs_hindex_median.bar_label(container, padding=4)
for container in fakul_scopus_hindex_mean.containers:
    fakul_scopus_hindex_mean.bar_label(container, padding=4, fmt='%.1f')
for container in fakul_gs_hindex_mean.containers:
    fakul_gs_hindex_mean.bar_label(container, padding=4, fmt='%.1f')

plt.show()

# %% [markdown]
# ## 5 Program Studi FPMIPA Teratas Berdasarkan Median dan Mean pada Scopus H Index dan Google Scholar H Index untuk Jenjang S2 dan S3

# %%
fakul_hindex = df_concat1

df_fakul_scopushindex_median = fakul_hindex.groupby('Nama Prodi')["scopus_h_index"].median().reset_index()
df_fakul_gshindex_median = fakul_hindex.groupby('Nama Prodi')["gs_h_index"].median().reset_index()

df_fakul_scopushindex_mean = fakul_hindex.groupby('Nama Prodi')["scopus_h_index"].mean().reset_index()
df_fakul_gshindex_mean = fakul_hindex.groupby('Nama Prodi')["gs_h_index"].mean().reset_index()


top_fakul_scopus_hindex_median = df_fakul_scopushindex_median.sort_values(by="scopus_h_index", ascending=False).head(5)
top_fakul_gs_hindex_median = df_fakul_gshindex_median.sort_values(by="gs_h_index", ascending=False).head(5)
top_fakul_scopus_hindex_mean = df_fakul_scopushindex_mean.sort_values(by="scopus_h_index", ascending=False).head(5)
top_fakul_gs_hindex_mean = df_fakul_gshindex_mean.sort_values(by="gs_h_index", ascending=False).head(5)


fig, axes = plt.subplots(4, 1, figsize=(10, 12))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle("5 Program Studi FPMIPA Teratas Berdasarkan Median dan Mean pada Scopus H Index dan Google Scholar H Index untuk Jenjang S1"
             , fontsize = 'large', fontweight = 'bold', y=1)

fakul_scopus_hindex_median = sns.barplot(x='scopus_h_index', y='Nama Prodi', data = top_fakul_scopus_hindex_median, palette="deep", ax=axes[0])
fakul_gs_hindex_median = sns.barplot(x='gs_h_index', y='Nama Prodi', data = top_fakul_gs_hindex_median, palette="deep", ax=axes[1])
fakul_scopus_hindex_mean = sns.barplot(x='scopus_h_index', y='Nama Prodi', data = top_fakul_scopus_hindex_mean, palette="deep", ax=axes[2])
fakul_gs_hindex_mean = sns.barplot(x='gs_h_index', y='Nama Prodi', data = top_fakul_gs_hindex_mean, palette="deep", ax=axes[3])

fakul_scopus_hindex_median.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Median Scopus H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_scopus_hindex_median.set_xlabel('Median Scopus H Index', fontsize = 12)
fakul_scopus_hindex_median.set_ylabel('')

fakul_gs_hindex_median.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Median Google Scholar H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_gs_hindex_median.set_xlabel('Median Google Scholar H Index', fontsize = 12)
fakul_gs_hindex_median.set_ylabel('')

fakul_scopus_hindex_mean.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Rata-rata Scopus H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_scopus_hindex_mean.set_xlabel('Rata-rata Scopus H Index', fontsize = 12)
fakul_scopus_hindex_mean.set_ylabel('')

fakul_gs_hindex_mean.set_title('5 Program Studi FPMIPA Teratas Berdasarkan Rata-rata Google Scholar H Index untuk Jenjang S1',fontweight="bold", size=13)
fakul_gs_hindex_mean.set_xlabel('Rata-rata Google Scholar H Index', fontsize = 12)
fakul_gs_hindex_mean.set_ylabel('')


fakul_gs_hindex_mean.text(0.1,7.5,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

for container in fakul_scopus_hindex_median.containers:
    fakul_scopus_hindex_median.bar_label(container, padding=4)
for container in fakul_gs_hindex_median.containers:
    fakul_gs_hindex_median.bar_label(container, padding=4)
for container in fakul_scopus_hindex_mean.containers:
    fakul_scopus_hindex_mean.bar_label(container, padding=4, fmt='%.1f')
for container in fakul_gs_hindex_mean.containers:
    fakul_gs_hindex_mean.bar_label(container, padding=4)

plt.show()

# %% [markdown]
# ### Distribusi Scopus H Index

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'scopus_h_index'

# %%
df['scopus_h_index'].describe()
# Out:
# count    186.000000
# mean       3.655914
# std        3.488962
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       31.000000
# Name: scopus_h_index, dtype: float64

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'scopus_h_index' Menggunakan Boxplot

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df, x="scopus_h_index", showmeans=True)
ax.set(xlabel='Scopus H Index')
# Out:
# [Text(0.5, 0, 'Scopus H Index')]

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'scopus_h_index' Setelah Praproses

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df_topten_scopus, x="scopus_h_index", showmeans=True)
ax.set(xlabel='Scopus H Index')
# Out:
# [Text(0.5, 0, 'Scopus H Index')]

# %%
plt.figure(figsize=(5.5, 4))
ax = sns.histplot(data=df_topten_scopus, x="scopus_h_index", binwidth=0.9)
ax.set(xlabel='Scopus H Index', ylabel='Jumlah Dosen')

for container in ax.containers:
    ax.bar_label(container, padding=2)

# %% [markdown]
# ### Distribusi Scopus H Index Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 10))

prodi = df_topten_scopus
df_prodi_scopus = prodi.groupby('Nama Prodi')["scopus_h_index"].median().reset_index()
prodi_scopus = df_prodi_scopus.sort_values(by="scopus_h_index", ascending=False)


# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', kemudian diurutkan
g = sns.boxplot(x ='scopus_h_index', y = 'Nama Prodi', data = df_topten_scopus, order = prodi_scopus['Nama Prodi'], palette="deep", width=0.7, showmeans=True)

g.set(xlabel='Scopus H Index', ylabel='Program Studi')
g.text(0, 24.2,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 24.7,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi Scopus H Index Setiap Fakultas", y=0.94, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi Scopus H Index Berdasarkan Gender Dosen Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='scopus_h_index', y = 'Nama Prodi', hue='Jenis Kelamin', data = df_topten_scopus, order = prodi_scopus['Nama Prodi'], palette=custom_palette1, width=0.8, showmeans=True)

g.set(xlabel='Scopus H Index', ylabel='Program Studi')
g.text(0, 23.4,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 23.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi Scopus H Index Berdasarkan Gender Setiap Program Studi FPMIPA" , y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi Scopus H Index Berdasarkan Pendidikan Terakhir Dosen Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'scopus_h_index' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='scopus_h_index', y = 'Nama Prodi', hue='Pendidikan Terakhir', data = df_topten_scopus, order = prodi_scopus['Nama Prodi'], palette="mako", width=0.8, showmeans=True)

g.set(xlabel='Scopus H Index', ylabel='Program Studi')
g.text(0, 23.4,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 23.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi Scopus H Index Berdasarkan Pendidikan Terakhir Setiap Program Studi FPMIPA" , y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA 3yr Score

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_3yr_score'

# %%
df['sinta_3yr_score'].describe()
# Out:
# count     186.000000
# mean      369.516129
# std       546.977249
# min         0.000000
# 25%        94.000000
# 50%       200.500000
# 75%       485.250000
# max      5308.000000
# Name: sinta_3yr_score, dtype: float64

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_3yr_score' Menggunakan Boxplot

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df, x="sinta_3yr_score", showmeans=True)
ax.set(xlabel='SINTA 3yr Score')
# Out:
# [Text(0.5, 0, 'SINTA 3yr Score')]

# %% [markdown]
# #### Drop Data 10 Persen Teratas dari Kolom 'sinta_3yr_score'

# %%
df_sort_sinta3yr = df.sort_values(by="sinta_3yr_score", ascending=False)

n = 10
df_topten = df_sort_sinta3yr.head(int(len(df_sort_sinta3yr)*(n/100)))
df_final = list(df_topten.nama.values)

# print(df_final)

df_topten_sinta3yr = df[~df.nama.isin(df_final)]

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_3yr_score' Setelah Praproses

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df_topten_sinta3yr, x="sinta_3yr_score", showmeans=True)
ax.set(xlabel='SINTA 3yr Score')
# Out:
# [Text(0.5, 0, 'SINTA 3yr Score')]

# %%
plt.figure(figsize=(5.5, 4))
ax = sns.histplot(data=df_topten_sinta3yr, x="sinta_3yr_score")
ax.set(xlabel='SINTA 3yr Score', ylabel='Jumlah Dosen')
for container in ax.containers:
    ax.bar_label(container, padding=2)

# %% [markdown]
# ### Distribusi SINTA 3yr Score Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 10))

prodi = df_topten_sinta3yr
df_prodi_sinta3yr = prodi.groupby('Nama Prodi')["sinta_3yr_score"].median().reset_index()
top_prodi_sinta3yr = df_prodi_sinta3yr.sort_values(by="sinta_3yr_score", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'sinta_3yr_score' dan y sebagai kolom 'Fakultas', kemudian diurutkan
g = sns.boxplot(x ='sinta_3yr_score', y = 'Nama Prodi', data = df_topten_sinta3yr, order = top_prodi_sinta3yr['Nama Prodi'], palette="deep", width=0.7, showmeans=True)

g.set(xlabel='SINTA 3yr Score', ylabel='Program Studi')
g.text(0, 23.2,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 23.7,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA 3yr Score Setiap Program Studi FPMIPA", y=0.95, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA 3yr Score Berdasarkan Gender Dosen Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'sinta_3yr_score' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='sinta_3yr_score', y = 'Nama Prodi', hue='Jenis Kelamin', data = df_topten_sinta3yr, order = top_prodi_sinta3yr['Nama Prodi'], palette=custom_palette1, width=0.8, showmeans=True)

g.set(xlabel='SINTA 3yr Score', ylabel='Program Studi')
g.text(0, 22.4,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 22.7,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA 3yr Score Berdasarkan Gender Setiap Program Studi FPMIPA", y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA 3yr Score Berdasarkan Pendidikan Terakhir Dosen Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'sinta_3yr_score' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='sinta_3yr_score', y = 'Nama Prodi', hue='Pendidikan Terakhir', data = df_topten_sinta3yr, order = top_prodi_sinta3yr['Nama Prodi'], palette="mako", width=0.8, showmeans=True)

g.set(xlabel='SINTA 3yr Score', ylabel='Program Studi')
g.text(0, 22.4,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 22.7,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA 3yr Score Berdasarkan Pendidikan Terakhir Setiap Program Studi FPMIPA", y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA Score

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_score'

# %%
df['sinta_score'].describe()
# Out:
# count      186.000000
# mean       793.258065
# std       1150.703619
# min          0.000000
# 25%        229.750000
# 50%        487.000000
# 75%        977.500000
# max      12610.000000
# Name: sinta_score, dtype: float64

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_score' Menggunakan Boxplot

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df, x="sinta_score", showmeans=True)
ax.set(xlabel='SINTA Score')
# Out:
# [Text(0.5, 0, 'SINTA Score')]

# %% [markdown]
# #### Drop Data 10 Persen Teratas dari Kolom 'sinta_score'

# %%
df_sort_sinta = df.sort_values(by="sinta_score", ascending=False)

n = 10
df_topten = df_sort_sinta.head(int(len(df_sort_sinta)*(n/100)))
df_final = list(df_topten.nama.values)

df_topten_sinta = df[~df.nama.isin(df_final)]

# %% [markdown]
# #### Menampilkan Distribusi Nilai pada Kolom 'sinta_score' Setelah Praproses

# %%
plt.figure(figsize=(5, 3))
ax = sns.boxplot(data=df_topten_sinta, x="sinta_score", showmeans=True)
ax.set(xlabel='SINTA Score')
# Out:
# [Text(0.5, 0, 'SINTA Score')]

# %%
plt.figure(figsize=(5.5, 4))
ax = sns.histplot(data=df_topten_sinta, x="sinta_score")
ax.set(xlabel='SINTA Score', ylabel='Jumlah Dosen')

for container in ax.containers:
    ax.bar_label(container, padding=2)

# %% [markdown]
# ### Distribusi SINTA Score Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 10))

prodi = df_topten_sinta
df_prodi_sinta = prodi.groupby('Nama Prodi')["sinta_score"].median().reset_index()
top_prodi_sinta = df_prodi_sinta.sort_values(by="sinta_score", ascending=False)

# deklarasi boxplot dengan x sebagai kolom 'sinta_score' dan y sebagai kolom 'Fakultas', kemudian diurutkan
fig = sns.boxplot(x ='sinta_score', y = 'Nama Prodi', data = df_topten_sinta, order = top_prodi_sinta['Nama Prodi'], palette="deep", width=0.7, showmeans=True)

fig.set(xlabel='SINTA Score', ylabel='Program Studi')
fig.text(0, 23.2,'Diurutkan berdasarkan median', fontstyle="normal")
fig.text(0, 23.7,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA Score Setiap Program Studi FPMIPA", y=0.95, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA Score Berdasarkan Gender Dosen Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'sinta_score' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='sinta_score', y = 'Nama Prodi', hue='Jenis Kelamin', data = df_topten_sinta, order = top_prodi_sinta['Nama Prodi'], palette=custom_palette1, width=0.8, showmeans=True)

g.set(xlabel='SINTA Score', ylabel='Program Studi')
g.text(0, 22,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 22.4,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA Score Berdasarkan Gender Setiap Program Studi FPMIPA", y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %% [markdown]
# ### Distribusi SINTA Score Berdasarkan Pendidikan Terakhir Dosen Setiap Program Studi FPMIPA

# %%
plt.figure(figsize=(10, 14))

# deklarasi boxplot dengan x sebagai kolom 'sinta_score' dan y sebagai kolom 'Fakultas', dibandingkan dengan kolom 'Jenis Kelamin'
# kemudian diurutkan
g = sns.boxplot(x ='sinta_score', y = 'Nama Prodi', hue='Pendidikan Terakhir', data = df_topten_sinta, order = top_prodi_sinta['Nama Prodi'], palette="mako", width=0.8, showmeans=True)

g.set(xlabel='SINTA Score', ylabel='Program Studi')
g.text(0, 22.4,'Diurutkan berdasarkan median', fontstyle="normal")
g.text(0, 22.8,'Data Agustus 2022', fontstyle="normal", fontweight="semibold")

plt.suptitle("Distribusi SINTA Score Berdasarkan Pendidikan Terakhir Setiap Program Studi FPMIPA", y=0.93, fontsize = 'large', fontweight = 'regular')
plt.show()

# %%
# pip install nbconvert
