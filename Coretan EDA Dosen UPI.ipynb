# %% [markdown]
# # Exploratory Data Analysis
# ### Dataset : https://github.com/crypter7054/Scraper-SINTA-UPI-2022
# ### Keterangan Atribut :
# - **name** = nama dosen
# - **sinta_id**  = id dosen pada website SINTA
# - **dept** = program studi
# - **sinta_score** = skor keseluruhan SINTA
# - **sinta_3yr_score** = skor SINTA dalam 3 tahun terakhir
# - **affil_score** = skor keseluruhan afiliasi
# - **affil_3yr_score** = skor afiliasi dalam 3 tahun terakhir
# - **scopus_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Scopus
# - **gs_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Google Scholar
# - **wos_h_index** = indeks untuk mengukur produktivitas berdasarkan jumlah publikasi dan sitasi dosen pada Web of Science
# - **scopus_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Scopus
# - **gs_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Google Scholar
# - **wos_i10_index** = skor dosen dalam publikasi artikel yang disitasi minimal oleh 10 artikel lain pada Web of Science
# - **scopus_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Scopus
# - **gs_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Google Scholar
# - **wos_g_index** = indeks untuk mengukur produktivitas berdasarkan distribusi sitasi dari publikasi dosen pada Web of Science
# - **scopus_article** = jumlah publikasi artikel dosen pada Scopus
# - **scopus_citation** = jumlah sitasi pada publikasi dosen pada Scopus
# - **scopus_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Scopus
# - **gs_article** = jumlah publikasi artikel dosen pada Google Scholar
# - **gs_citation** = jumlah sitasi pada publikasi dosen pada Google Scholar
# - **gs_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Google Scholar
# - **wos_article** = jumlah publikasi artikel dosen pada Web of Science
# - **wos_citation** = jumlah sitasi pada publikasi dosen pada Web of Science
# - **wos_cited_document** = jumlah publikasi lain yang disitasi oleh dosen pada Web of Science

# %% [markdown]
# ### Import Library

# %%
# %matplotlib inline
import numpy as np                  
import pandas as pd                 
import matplotlib.pyplot as plt     
import seaborn as sns

# %% [markdown]
# ### Read Data dan Praproses

# %%
df = pd.read_csv("C:\\Users\\LENOVO\\Scraper-SINTA-UPI-2022\\EDA data\\dosen.csv", encoding='utf-8')    
df2 = pd.read_csv("C:\\Users\\LENOVO\\Scraper-SINTA-UPI-2022\\EDA data\\juli_2022_joinSinta_publik.csv", sep=";") 

df = df.drop(columns=['affil_3yr_score', 'affil_score', 'name'])
df2 = df2.drop(columns=['scopus_h_index', 'gs_h_index', 'sinta_3yr_score', 'sinta_score', 
                        'affil_3yr_score', 'affil_score', 'No']) 
    
data_recap = (pd.merge(df2, df, left_on='sinta_id', right_on='sinta_id', how='left'))

data_recap = data_recap[data_recap['NIP'].notna()]
data_recap = data_recap[data_recap['Gol'].notna()]
data_recap = data_recap[data_recap['Kode Prodi'].notna()]
data_recap = data_recap[data_recap['sinta_id'].notna()]
data_recap = data_recap[data_recap['scopus_h_index'].notna()]

# %%
data_recap.head(5)
# Out:
#            NIP                                     nama Stat.Peg   Gol  \
# 0  1,96202E+17  Prof. Dr. H. M. Solehuddin, M.Pd., M.A.      PNS  IV/c
# 1  1,95306E+17   Prof. Dr. H. Mohammad Ali, M.Pd., M.A.      PNS  IV/e
# 2  1,95404E+17        Prof. Dr. Hj. Ihat Hatimah, M.Pd.      PNS  IV/e
# 3  1,95501E+17         Prof. Dr. H. Achmad Hufad, M.Ed.      PNS  IV/e
# 4  1,96111E+17        Prof. Dr. H. Mustofa Kamil, M.Pd.      PNS  IV/e
#
#   Jabatan Fungsional Pendidikan Terakhir Fakultas  Kode Prodi  \
# 0         Guru Besar                  S3      FIP     86001.0
# 1         Guru Besar                  S3      FIP     86021.0
# 2         Guru Besar                  S3      FIP     86005.0
# 3         Guru Besar                  S3      FIP     86002.0
# 4         Guru Besar                  S3      FIP     86105.0
#
#                      Nama Prodi   sinta_id  ... wos_g_index  scopus_article  \
# 0  Bimbingan Dan Konseling (S3)  5995348.0  ...         2.0            16.0
# ...

# %%
data_recap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1424 entries, 0 to 1509
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NIP                    1424 non-null   object
#  1   nama                   1424 non-null   object
#  2   Stat.Peg               1424 non-null   object
#  3   Gol                    1424 non-null   object
#  4   Jabatan Fungsional     1424 non-null   object
#  5   Pendidikan Terakhir    1424 non-null   object
#  6   Fakultas               1424 non-null   object
#  7   Kode Prodi             1424 non-null   float64
#  8   Nama Prodi             1424 non-null   object
#  9   sinta_id               1424 non-null   float64
#  10  dept                   1424 non-null   object
#  11  sinta_score            1424 non-null   float64
#  12  sinta_3yr_score        1424 non-null   float64
#  13  scopus_h_index         1424 non-null   float64
# ...

# %% [markdown]
# ### Distribusi SINTA Score Per Fakultas

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.boxplot(x ='sinta_score', y ='Fakultas', data = data_recap, palette='Paired')

fig.set(xlabel='SINTA Score', ylabel='Fakultas')
fig.set_title('Persebaran SINTA Score Per Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribusi SINTA 3yr Score Per Fakultas

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.boxplot(x ='sinta_3yr_score', y ='Fakultas', data = data_recap, palette ='Paired')

fig.set(xlabel='SINTA 3yr Score', ylabel='Fakultas')
fig.set_title('Persebaran SINTA 3yr Score Per Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribusi SINTA Score Per Fakultas (Bar Plot)

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.barplot(x ='sinta_score', y ='Fakultas', data = data_recap)

fig.set(xlabel='SINTA Score', ylabel='Fakultas')
fig.set_title('Persebaran SINTA Score Per Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribusi SINTA 3yr Score Per Fakultas (Bar Plot)

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.barplot(x ='sinta_3yr_score', y ='Fakultas', data = data_recap)

fig.set(xlabel='SINTA 3yr Score', ylabel='Fakultas')
fig.set_title('Persebaran SINTA 3yr Score Per Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Persebaran Dosen Berdasarkan Fakultas

# %%
plt.figure(figsize=(12, 12))
g = sns.displot(data_recap, y="Fakultas")
# g.set_title('Persebaran Jumlah Dosen Berdasarkan Fakultas', fontsize=16)
g.fig.set_figwidth(20)

# %% [markdown]
# ### Persebaran Dosen Berdasarkan Pendidikan Terakhir

# %%
plt.figure(figsize=(5, 5))
g = sns.displot(data_recap, x="Pendidikan Terakhir")
g.fig.set_figwidth(5)

# %% [markdown]
# ### Distribusi SINTA 3yr Score

# %%
g = sns.displot(data_recap, x="sinta_3yr_score", kind="kde")
g.fig.set_figwidth(10)

# %% [markdown]
# ### Distribusi SINTA Score

# %%
g = sns.displot(data_recap, x="sinta_score", kind="kde")
g.fig.set_figwidth(10)

# %% [markdown]
# ### Distribusi Jumlah Artikel Scopus Berdasarkan Fakultas

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.barplot(x ='scopus_article', y ='Fakultas', data = data_recap, palette ='Paired')

fig.set(xlabel='Scopus Artikel', ylabel='Fakultas')
fig.set_title('Distribusi Jumlah Artikel Scopus Berdasarkan Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribusi Jumlah Sitasi Artikel Scopus Berdasarkan Fakultas

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.barplot(x ='scopus_citation', y ='Fakultas', data = data_recap, palette ='Paired')

fig.set(xlabel='Scopus Citation', ylabel='Fakultas')
fig.set_title('Distribusi Jumlah Sitasi Artikel Scopus Berdasarkan Fakultas', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribusi Jumlah Publikasi yang Disitasi pada Artikel Scopus Berdasarkan Fakultas

# %%
plt.rcParams["figure.figsize"] = [13, 6]
plt.rcParams["figure.autolayout"] = True

fig = sns.barplot(x ='scopus_cited_document', y ='Fakultas', data = data_recap, palette ='Paired')

fig.set(xlabel='Scopus Cited Document', ylabel='Fakultas')
fig.set_title('Distribusi Jumlah Publikasi yang Disitasi pada Artikel Scopus Berdasarkan Fakultas', fontsize=16)
plt.show()
